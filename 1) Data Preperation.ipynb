# %% [markdown]
# # Data Preparation & Exploration

# %% [markdown]
# In this notebook, I load, clean and join relevant datafiles, before saving the final product for further analysis

# %% [markdown]
# The steps that are performed in this notebook are the following:
#
# 1) Data pre-processing
#     - Loading packages
#     - Reading in the data and adding variables where necessary
#     - Selecting only political online articles
#     - Joining the two dataframes
#     - Removing duplicates
#     - Transforming column types
#     - Cleaning up the text data
#     - Upating article length
#     - Removing articles that could not be scraped due to them being behind a paywall
#
# 2) NLP to stem text and remove stopwords
#
# 3) Creating dummy variables
#
# 4) Saving the clean data
#
# 5) Exploring the distribution of the data among different modalities and outlets

# %% [markdown]
# ### 1) Data pre-processing
#
# #### a) Loading packages

# %%
#import pandas
import pandas as pd
from pandas import read_excel
#import numpy
import numpy as np
#load SpaCy
import spacy
#import German language model
import de_core_news_md
#define nlp pipe
nlp = de_core_news_md.load()

# %% [markdown]
# #### b) Reading in the data and adding variables where necessary

# %%
#read print data
printdata = pd.read_csv("printdata_19Apr_to_08June.csv", encoding = "ISO-8859-1")
#transform data into a dataframe for easier analysis
df_print = pd.DataFrame(printdata)
#add relevant columns for later joining
df_print["Modality"] = "print"
df_print["Teaser"] = ""
df_print["url"] = "none"
#adapt the length column by applying a function
#definingthe function
def removewords(string):
    return string.split(" ")[0].strip()
#applying the function
df_print["Length"] = df_print["Length"].apply(removewords)
#rename columns for later joining
df_print = df_print.rename(columns={"Section":"Category"})
#select relevant columns
df_print = df_print[["ID", "Newspaper", "Date", "Length", "Category", "Author", "Headline", "Teaser", "Article", "Modality", "url"]] 
df_print.head(3)
# Out:
#    ID         Newspaper        Date Length                       Category  \
# 0   1  Aachener Zeitung  2020-04-29    787  MEINUNG UND HINTERGRUND; S. 4
# 1   2  Aachener Zeitung  2020-04-22    509                  POLITIK; S. 2
# 2   3  Aachener Zeitung  2020-04-29    598                   DÜREN; S. 11
#
#   Author                                           Headline Teaser  \
# 0    NaN  Appelle für den Wahlrecht-Kraftakt; Den Partei...
# 1    NaN  Petition soll Regierung Netanjahu verhindern; ...
# 2    NaN  13 Tage für Griechenland statt Inden aktiv; Di...
#
#                                              Article Modality   url
# 0  Von Gregor Mayntz   Berlin Wenn man Abgeordnet...    print  none
# 1    Von Stefanie Järkel   Jerusalem Die künftige...    print  none
# 2    Von Guido Jansen   Inden Ist es nötig, dass ...    print  none

# %%
df_print.groupby("Newspaper").count()
# Out:
#                                                 ID  Date  Length  Category  \
# Newspaper
# Aachener Zeitung                               991   984     991       991
# Der Tagesspiegel                              1298  1293    1298      1298
# Die Welt                                       833   833     833       833
# Rheinische Post                               3285  3269    3285      3285
# Stuttgarter Zeitung                           1294  1294    1294      1294
# Süddeutsche Zeitung (inkl. Regionalausgaben)  3875  3862    3875      3875
#
#                                               Author  Headline  Teaser  \
# Newspaper
# Aachener Zeitung                                   0       991     991
# Der Tagesspiegel                                 398      1298    1298
# Die Welt                                         657       833     833
# Rheinische Post                                 1875      3285    3285
# Stuttgarter Zeitung                             1116      1294    1294
# Süddeutsche Zeitung (inkl. Regionalausgaben)    3723      3875    3875
#
#                                               Article  Modality   url
# Newspaper
# Aachener Zeitung                                  991       991   991
# Der Tagesspiegel                                 1298      1298  1298
# Die Welt                                          833       833   833
# Rheinische Post                                  3285      3285  3285
# Stuttgarter Zeitung                              1294      1294  1294
# Süddeutsche Zeitung (inkl. Regionalausgaben)     3875      3875  3875

# %%
len(df_print)
# Out:
# 11576

# %%
#read online data
df_online = read_excel("online_data_complete.xlsx")
#rename columns
df_online = df_online.rename(columns={"_source.title_rss": "Headline", "_source.doctype": "Newspaper", "_source.publication_date": "Date", "_source.teaser_rss": "Teaser", "_source.text": "Article", "_source.category": "Category", "_source.url":"url"})
#add columns for later joining
df_online["Length"] = 0 
df_online["Modality"] = "online"
#reset index and add unique ID column
df_onine = df_online.reset_index(drop=True)
df_online["ID"] = range(100000, 100000+len(df_online))
df_online["Author"] = ""
#select relevant columns
df_online = df_online[["ID", "Newspaper", "Date", "Length", "Category", "Author", "Headline", "Teaser", "Article", "Modality", "url"]]
df_online.head(3)
# Out:
#        ID               Newspaper                 Date  Length  Category  \
# 0  100000   rheinische post (www)  2020-05-27T22:15:00       0  Panorama
# 1  100001  aachener zeitung (www)  2020-05-28T15:47:26       0     Sport
# 2  100002  aachener zeitung (www)  2020-05-28T15:27:00       0     Sport
#
#   Author                                           Headline  \
# 0         Kritik an schleppender Digitalisierung: „Dem D...
# 1         DFB-Sportgericht: Kölner Bornauw nach Rot in S...
# 2         Niederlage bei der TSG Hoffenheim: Wenn sich d...
#
#                                               Teaser  \
# 0  <img src="https://rp-online.de/imgs/32/8/4/1/6...
# 1  <img src="https://www.aachener-zeitung.de/imgs...
# 2  <img src="https://www.aachener-zeitung.de/imgs...
#
#                                              Article Modality  \
# 0            erD efCh sde euDhcstne unBdsemtenab ...   online
# 1  Der 21 Jahre alte Defensivspieler hatte in der...   online
# 2           sE gtib cahu rüf lreluabßF edeis ,agT...   online
#
#                                                  url
# 0  https://rp-online.de/panorama/coronavirus/coro...
# 1  https://www.aachener-zeitung.de/sport/fussball...
# 2  https://www.aachener-zeitung.de/sport/fussball...

# %%
len(df_online)
# Out:
# 7992

# %%
df_online.groupby("Newspaper").count()
# Out:
#                                ID  Date  Length  Category  Author  Headline  \
# Newspaper
# aachener zeitung (www)       1463  1463    1463      1439    1463      1463
# der tagesspiegel (www)       1084  1084    1084      1084    1084      1084
# die welt (www)               1705  1705    1705      1660    1705      1705
# rheinische post (www)        1528  1528    1528      1526    1528      1528
# stuttgarter zeitung (www)    1029  1029    1029       992    1029      1029
# sueddeutsche (www)             53    53      53         0      53        53
# sueddeutschet politik (www)  1130  1130    1130       110    1130      1130
#
#                              Teaser  Article  Modality   url
# Newspaper
# aachener zeitung (www)         1463     1446      1463  1463
# der tagesspiegel (www)         1084     1074      1084  1084
# die welt (www)                 1696      845      1705  1705
# rheinische post (www)          1528     1503      1528  1528
# stuttgarter zeitung (www)      1029      987      1029  1029
# sueddeutsche (www)               53        0        53    53
# sueddeutschet politik (www)    1130     1126      1130  1130

# %% [markdown]
# #### c) Selecting only political online articles

# %%
len(df_online)
# Out:
# 7992

# %%
#first I remove articles that weren't parsed correctly
df_online = df_online[~df_online["Article"].str.startswith('    ', na=False)]
#next I remove Impressum articles from die Süddeutsche
df_online = df_online[~df_online["Article"].str.contains("HERAUSGEGEBEN VOM SÜDDEUTSCHEN VERLAG", na= False)]
#after that I do the same for Stuttgarter Zeitung
df_online = df_online[~df_online["Article"].str.contains("Impressum Stuttgarter Zeitung Verlagsgesellschaft", na= False)]
#next I include only political articles for the online dataset
relevant_articles = df_online[df_online['url'].astype(str).str.contains("politik")]
relevant_articles2 = df_online[df_online["Category"].astype(str).str.contains("Politik")]
df_online = pd.concat([relevant_articles, relevant_articles2])
len(df_online)
# Out:
# 2236

# %% [markdown]
# #### d) Joining the two dataframes

# %%
#join the two datasets
df = pd.concat([df_online, df_print])
len(df)
# Out:
# 13812

# %%
#inspect df
df.head()
# Out:
#         ID                    Newspaper                 Date Length Category  \
# 6   100006  sueddeutschet politik (www)  2020-05-28T15:34:08      0      NaN
# 8   100008  sueddeutschet politik (www)  2020-05-28T17:01:43      0      NaN
# 21  100021               die welt (www)  2020-05-28T17:49:45      0  Politik
# 24  100024       aachener zeitung (www)  2020-05-28T03:01:52      0  Politik
# 28  100028  sueddeutschet politik (www)  2020-05-28T03:12:25      0      NaN
#
#    Author                                           Headline  \
# 6          SZ Espresso: Nachrichten kompakt - die Übersic...
# 8                               Kommunalpolitik: Abgeblendet
# 21               Wie Söder es schaffte, die AfD zu halbieren
# 24         Länder planen Öffnung: Streit über Schulen und...
# 28           Mecklenburg-Vorpommern: Grundgesetz als Maßstab
#
#                                                Teaser  \
# 6   <p>Was heute wichtig war - und was Sie auf SZ....
# 8                 <p>Bayreuths Stadtrat im Stream</p>
# 21  Die Corona-Krise lässt die CSU erstarken und b...
# 24  <img src="https://www.aachener-zeitung.de/imgs...
# 28  <img src="https://media-cdn.sueddeutsche.de/im...
#
#                                               Article Modality  \
# 6   Das Wichtigste zum Coronavirus. Berufstätige M...   online
# 8   Livestream aus dem Stadtrat, das klingt transp...   online
# 21                                                NaN   online
# 24  Der Streit über die Wiederöffnung von Schulen ...   online
# 28  An diesem Donnerstag trifft sich das neue Land...   online
#
#                                                   url
# 6   https://www.sueddeutsche.de/politik/nachrichte...
# 8   https://www.sueddeutsche.de/bayern/kommunalpol...
# 21  https://www.welt.de/politik/deutschland/plus20...
# 24  https://www.aachener-zeitung.de/politik/deutsc...
# 28  https://www.sueddeutsche.de/politik/barbara-bo...

# %% [markdown]
# #### e) Remove duplicates

# %%
#check the size of the dataset
len(df)
# Out:
# 13812

# %%
#create a list of duplicates
duplicates = df[df.duplicated(["Article"])]
len(duplicates)
# Out:
# 2198

# %%
#remove duplicates
df.drop_duplicates(subset ="Article", keep = "first", inplace = True) 
len(df)
# Out:
# 11614

# %%
#check for duplicates
duplicates = df[df.duplicated(["Article"])]
len(duplicates)
# Out:
# 0

# %% [markdown]
# #### f) Transform column types

# %%
df.dtypes
# Out:
# ID            int64
# Newspaper    object
# Date         object
# Length       object
# Category     object
# Author       object
# Headline     object
# Teaser       object
# Article      object
# Modality     object
# url          object
# dtype: object

# %%
df["Article"] = df["Article"].astype(str)
df["Length"] = df["Length"].astype(int)
df["Category"] = df["Category"].astype(str)
df["Author"] = df["Author"].astype(str)
df["Modality"] = df["Modality"].astype(str)
#see if it worked
df.dtypes
# Out:
# ID            int64
# Newspaper    object
# Date         object
# Length        int64
# Category     object
# Author       object
# Headline     object
# Teaser       object
# Article      object
# Modality     object
# url          object
# dtype: object

# %% [markdown]
# #### g) Cleaning up the text data

# %%
#show the 1000 most frequent words in the df, in order to spot potential issues that require cleaning
from collections import Counter
Counter(" ".join(df["Article"]).split()).most_common(1000)
# Out:
# [('die', 184266),
#  ('der', 179854),
#  ('und', 120816),
#  ('in', 96811),
#  ('den', 65387),
#  ('zu', 56257),
#  ('das', 50980),
#  ('für', 49871),
#  ('von', 49312),
#  ('mit', 42321),
#  ('nicht', 41844),
#  ('sich', 41765),
#  ('im', 39368),
#  ('auf', 37731),
#  ('ist', 36925),
#  ('es', 36292),
#  ('Die', 34960),
#  ('eine', 34752),
#  ('des', 33530),
#  ('auch', 33193),
#  ('dass', 32647),
#  ('dem', 30987),
#  ('ein', 29845),
#  ('als', 27989),
#  ('an', 22839),
#  ('-', 21629),
#  ('sie', 20705),
#  ('wie', 20130),
#  ('am', 19750),
#  ('bei', 18261),
#  ('er', 17646),
#  ('um', 17202),
#  ('einer', 16893),
#  ('hat', 16837),
#  ('noch', 16615),
#  ('aus', 16336),
#  ('Das', 16122),
#  ('aber', 15784),
#  ('nach', 15740),
#  ('einen', 15709),
#  ('Der', 15069),
#  ('sind', 14097),
#  ('vor', 14094),
#  ('einem', 13697),
#  ('so', 13417),
#  ('nur', 13073),
#  ('oder', 12800),
#  ('über', 12787),
#  ('werden', 12650),
#  ('wird', 12195),
#  ('mehr', 11740),
#  ('zum', 11662),
#  ('man', 11294),
#  ('wieder', 10825),
#  ('wir', 10725),
#  ('sei', 10655),
#  ('zur', 10312),
#  ('In', 10204),
#  ('haben', 10040),
#  ('war', 9987),
#  ('bis', 9984),
#  ('Es', 9077),
#  ('sagte', 8618),
#  ('Sie', 8571),
#  ('wenn', 8507),
#  ('gegen', 8473),
#  ('werden.', 8122),
#  ('sagt', 7647),
#  ('hatte', 7583),
#  ('unter', 7552),
#  ('schon', 7418),
#  ('durch', 7373),
#  ('nun', 7093),
#  ('Und', 6913),
#  ('dann', 6891),
#  ('habe', 6858),
#  ('keine', 6711),
#  ('ihre', 6704),
#  ('Auch', 6626),
#  ('soll', 6446),
#  ('Menschen', 6334),
#  ('Euro', 6200),
#  ('diese', 6119),
#  ('alle', 6048),
#  ('jetzt', 5915),
#  ('vom', 5896),
#  ('Er', 5668),
#  ('Prozent', 5635),
#  ('wurde', 5609),
#  ('seit', 5531),
#  ('was', 5428),
#  ('kann', 5370),
#  ('immer', 5360),
#  ('viele', 5292),
#  ('gibt', 5260),
#  ('Deutschland', 5230),
#  ('ich', 5222),
#  ('seine', 5202),
#  ('zwei', 5185),
#  ('dieser', 5078),
#  ('sein', 4854),
#  ('damit', 4840),
#  ('bereits', 4832),
#  ('weil', 4781),
#  ('muss', 4706),
#  ('etwa', 4679),
#  ('Im', 4593),
#  ('Jahr', 4545),
#  ('ist,', 4527),
#  ('werden,', 4524),
#  ('anderen', 4393),
#  ('sehr', 4371),
#  ('will', 4359),
#  ('seiner', 4316),
#  ('Jahren', 4309),
#  ('sollen', 4224),
#  ('diesem', 4205),
#  ('Ende', 4198),
#  ('eines', 4133),
#  ('müssen', 4122),
#  ('neue', 4044),
#  ('uns', 4041),
#  ('sondern', 4038),
#  ('Aber', 4034),
#  ('Ein', 3936),
#  ('viel', 3918),
#  ('wegen', 3881),
#  ('Doch', 3872),
#  ('Mai', 3819),
#  ('geht', 3785),
#  ('Für', 3777),
#  ('ob', 3728),
#  ('Corona-Krise', 3726),
#  ('seien', 3716),
#  ('Stadt', 3683),
#  ('zwischen', 3678),
#  ('allem', 3658),
#  ('da', 3654),
#  ('selbst', 3647),
#  ('ohne', 3633),
#  ('Millionen', 3625),
#  ('Land', 3598),
#  ('ihrer', 3546),
#  ('So', 3511),
#  ('können', 3453),
#  ('erst', 3436),
#  ('ihren', 3434),
#  ('beim', 3431),
#  ('andere', 3411),
#  ('waren', 3378),
#  ('vergangenen', 3376),
#  ('Regierung', 3325),
#  ('Krise', 3322),
#  ('Wochen', 3304),
#  ('Graphic', 3289),
#  ('werde', 3242),
#  ('neuen', 3239),
#  ('Berlin', 3233),
#  ('Wie', 3231),
#  ('drei', 3214),
#  ('Milliarden', 3206),
#  ('doch', 3195),
#  ('ist.', 3188),
#  ('Eine', 3167),
#  ('Am', 3164),
#  ('Mit', 3130),
#  ('sowie', 3129),
#  ('SPD', 3126),
#  ('ihr', 3093),
#  ('kein', 3051),
#  ('Jahre', 3040),
#  ('Zeit', 2975),
#  ('wäre', 2960),
#  ('gut', 2941),
#  ('wurden', 2939),
#  ('ersten', 2921),
#  ('Wir', 2909),
#  ('also', 2871),
#  ('dafür', 2862),
#  ('Politik', 2839),
#  ('Bürgermeister', 2805),
#  ('ins', 2800),
#  ('Trump', 2788),
#  ('ganz', 2773),
#  ('Nach', 2752),
#  ('rund', 2748),
#  ('dort', 2708),
#  ('Grünen', 2696),
#  ('Wenn', 2695),
#  ('könnte', 2692),
#  ('seinen', 2689),
#  ('gerade', 2681),
#  ('weiter', 2680),
#  ('Woche', 2676),
#  ('einmal', 2643),
#  ('Ich', 2625),
#  ('können.', 2620),
#  ('allerdings', 2612),
#  ('wird.', 2611),
#  ('Pandemie', 2609),
#  ('Bei', 2581),
#  ('Unternehmen', 2579),
#  ('Als', 2566),
#  ('haben.', 2540),
#  ('hatten', 2533),
#  ('etwas', 2507),
#  ('heißt', 2493),
#  ('derzeit', 2492),
#  ('hier', 2491),
#  ('Kinder', 2489),
#  ('\x96', 2461),
#  ('weitere', 2459),
#  ('denen', 2450),
#  ('ihm', 2447),
#  ('ihn', 2443),
#  ('Juni', 2439),
#  ('Was', 2424),
#  ('diesen', 2424),
#  ('sein.', 2424),
#  ('März', 2416),
#  ('Bundesregierung', 2396),
#  ('zwar', 2377),
#  ('dazu', 2364),
#  ('Auf', 2363),
#  ('ab', 2345),
#  ('steht', 2332),
#  ('sein,', 2322),
#  ('sieht', 2288),
#  ('alles', 2269),
#  ('haben,', 2268),
#  ('April', 2255),
#  ('Foto:', 2238),
#  ('wo', 2234),
#  ('gab', 2233),
#  ('seinem', 2233),
#  ('Merkel', 2229),
#  ('vielen', 2224),
#  ('Montag', 2222),
#  ('ja', 2218),
#  ('Denn', 2215),
#  ('dies', 2211),
#  ('Virus', 2196),
#  ('würde', 2195),
#  ('hat.', 2188),
#  ('sollte', 2185),
#  ('Dass', 2183),
#  ('weniger', 2178),
#  ('nicht.', 2153),
#  ('große', 2146),
#  ('wollen', 2135),
#  ('davon', 2132),
#  ('hätten', 2118),
#  ('USA', 2104),
#  ('Schulen', 2102),
#  ('000', 2099),
#  ('Geld', 2089),
#  ('großen', 2087),
#  ('wohl', 2069),
#  ('Partei', 2068),
#  ('müsse', 2065),
#  ('würden', 2054),
#  ('jedoch', 2045),
#  ('dabei', 2036),
#  ('wird,', 2035),
#  ('lange', 2027),
#  ('Diese', 2024),
#  ('dieses', 2019),
#  ('Corona', 2014),
#  ('hat,', 2000),
#  ('an.', 1998),
#  ('Maßnahmen', 1996),
#  ('bisher', 1993),
#  ('gar', 1987),
#  ('fast', 1984),
#  ('sind.', 1974),
#  ('Länder', 1970),
#  ('Man', 1964),
#  ('Präsident', 1956),
#  ('allen', 1947),
#  ('gilt', 1947),
#  ('Wirtschaft', 1943),
#  ('Zahl', 1939),
#  ('an,', 1934),
#  ('könne', 1922),
#  ('Von', 1919),
#  ('Bürger', 1916),
#  ('sogar', 1908),
#  ('könnten', 1880),
#  ('keinen', 1868),
#  ('eigenen', 1865),
#  ('darauf', 1858),
#  ('vier', 1858),
#  ('deutlich', 1853),
#  ('mal', 1849),
#  ('sind,', 1847),
#  ('denn', 1845),
#  ('deutschen', 1844),
#  ('nichts', 1843),
#  ('schnell', 1824),
#  ('fünf', 1811),
#  ('Teil', 1811),
#  ('heute', 1809),
#  ('Fall', 1804),
#  ('China', 1804),
#  ('2020', 1792),
#  ('besonders', 1785),
#  ('nicht,', 1778),
#  ('zehn', 1767),
#  ('deshalb', 1764),
#  ('Anfang', 1760),
#  ('(CDU)', 1759),
#  ('hätte', 1753),
#  ('Beispiel', 1751),
#  ('beiden', 1740),
#  ('Tag', 1732),
#  ('unserer', 1727),
#  ('aus.', 1724),
#  ('kaum', 1712),
#  (',,Wir', 1711),
#  ('dürfen', 1698),
#  ('während', 1694),
#  ('Bund', 1693),
#  ('Da', 1688),
#  ('sollten', 1687),
#  ('Mittwoch', 1682),
#  ('CDU', 1678),
#  ('vor,', 1674),
#  ('Deutschen', 1670),
#  ('erste', 1657),
#  ('kommt', 1655),
#  ('laut', 1652),
#  ('aus,', 1648),
#  ('Thema', 1634),
#  ('ihrem', 1632),
#  ('ihnen', 1626),
#  ('Wahl', 1625),
#  ('EU', 1619),
#  ('Sitzung', 1613),
#  ('möglich', 1596),
#  ('Wer', 1596),
#  ('deren', 1592),
#  ('sechs', 1589),
#  ('wenig', 1585),
#  ('Corona-Pandemie', 1583),
#  ('Leben', 1578),
#  ('nächsten', 1578),
#  ('worden.', 1567),
#  ('Entscheidung', 1563),
#  ('Europa', 1558),
#  ('Dienstag', 1556),
#  ('können,', 1549),
#  ('Staat', 1547),
#  ('kommen', 1538),
#  ('Coronavirus', 1537),
#  ('stehen', 1533),
#  ('mich', 1529),
#  ('aller', 1527),
#  ('Frage', 1523),
#  ('Polizei', 1517),
#  ('er.', 1516),
#  ('Donnerstag', 1507),
#  ('ebenfalls', 1507),
#  ('anderem', 1504),
#  ('Weg', 1502),
#  ('CSU', 1501),
#  ('Lage', 1500),
#  ('einige', 1497),
#  ('20', 1495),
#  ('2019', 1492),
#  ('unsere', 1485),
#  ('Ministerpräsident', 1481),
#  ('Vor', 1474),
#  ('(SPD)', 1474),
#  ('Arbeit', 1473),
#  ('worden', 1467),
#  ('zunächst', 1458),
#  ('eher', 1457),
#  ('Dabei', 1449),
#  ('Seit', 1446),
#  ('kommenden', 1442),
#  ('Union', 1441),
#  ('politischen', 1440),
#  ('liegt', 1436),
#  ('später', 1434),
#  ('Mitte', 1431),
#  ('Tagen', 1426),
#  ('Blick', 1426),
#  ('oft', 1425),
#  ('zuletzt', 1411),
#  ('Söder', 1408),
#  ('zudem', 1399),
#  ('Seite', 1398),
#  ('politische', 1396),
#  ('Damit', 1395),
#  ('pro', 1395),
#  ('AfD', 1379),
#  ('gehen', 1378),
#  ('Kommunen', 1374),
#  ('Eltern', 1373),
#  ('kam', 1372),
#  ('Situation', 1369),
#  ('München', 1367),
#  ('machen', 1366),
#  ('bislang', 1363),
#  ('jeder', 1354),
#  ('Zudem', 1353),
#  ('weiterhin', 1342),
#  ('es,', 1332),
#  ('letzten', 1331),
#  ('deutsche', 1325),
#  ('Berliner', 1321),
#  ('R', 1321),
#  ('darf', 1319),
#  ('Kritik', 1318),
#  ('Freitag', 1318),
#  ('Ländern', 1317),
#  ('Nun', 1311),
#  ('solche', 1310),
#  ('weit', 1310),
#  ('macht', 1306),
#  ('Welt', 1301),
#  ('nie', 1297),
#  ('mir', 1294),
#  (',,Die', 1281),
#  ('kann.', 1280),
#  ('eigentlich', 1269),
#  ('Markus', 1263),
#  ('bleibt', 1260),
#  ('erklärte', 1256),
#  ('Unterstützung', 1247),
#  ('darüber', 1247),
#  ('Verwaltung', 1247),
#  ('vor.', 1247),
#  ('öffentlichen', 1243),
#  ('50', 1238),
#  ('meisten', 1237),
#  ('Michael', 1225),
#  ('Staaten', 1224),
#  ('Um', 1218),
#  ('besser', 1218),
#  ('Amt', 1217),
#  ('Angela', 1216),
#  ('müssten', 1215),
#  ('Mitarbeiter', 1207),
#  ('stark', 1200),
#  ('sehen', 1200),
#  ('Lockerungen', 1197),
#  ('Viele', 1197),
#  ('Peter', 1197),
#  ('sei,', 1194),
#  ('30', 1192),
#  ('weiteren', 1191),
#  ('einfach', 1190),
#  ('100', 1181),
#  ('genau', 1179),
#  ('welche', 1176),
#  ('war,', 1173),
#  ('Den', 1172),
#  ('Thomas', 1171),
#  ('Zu', 1169),
#  ('bin', 1168),
#  ('Sicht', 1166),
#  ('Kreis', 1158),
#  ('Kosten', 1155),
#  ('(CSU)', 1153),
#  ('gebe', 1147),
#  ('war.', 1144),
#  ('zumindest', 1142),
#  ('sei.', 1141),
#  ('inzwischen', 1140),
#  ('trotz', 1136),
#  ('Bundestag', 1135),
#  ('FDP', 1135),
#  ('dessen', 1133),
#  ('künftig', 1133),
#  ('insgesamt', 1132),
#  ('Zeiten', 1131),
#  ('An', 1126),
#  ('ab.', 1126),
#  ('Platz', 1125),
#  ('Dies', 1124),
#  ('soll.', 1114),
#  ('Folgen', 1111),
#  ('damals', 1110),
#  ('dürfte', 1110),
#  ('natürlich', 1106),
#  ('Schüler', 1105),
#  ('auf,', 1104),
#  ('Kanzlerin', 1104),
#  ('gegenüber', 1101),
#  ('Bayern', 1100),
#  ('Mehrheit', 1098),
#  ('lässt', 1096),
#  ('1.', 1095),
#  ('hält', 1094),
#  ('müssen.', 1094),
#  ('Mal', 1089),
#  ('Antrag', 1083),
#  ('Beginn', 1082),
#  ('Aus', 1076),
#  ('bleiben', 1071),
#  ('gemeinsam', 1069),
#  ('dagegen', 1068),
#  ('hinter', 1067),
#  ('per', 1067),
#  ('Andreas', 1064),
#  ('Dann', 1062),
#  ('Tage', 1061),
#  ('Monaten', 1057),
#  ('\x84Wir', 1057),
#  ('Gemeinde', 1055),
#  ('neu', 1054),
#  ('wollte', 1051),
#  ('wurde.', 1048),
#  ('lassen.', 1046),
#  ('geben', 1044),
#  ('neben', 1043),
#  ('Fragen', 1041),
#  ('Euro.', 1041),
#  ('Politiker', 1038),
#  ('mindestens', 1038),
#  ('Zukunft', 1037),
#  ('wer', 1035),
#  ('anders', 1035),
#  ('zuvor', 1034),
#  ('hatte.', 1031),
#  ('Gemeinderat', 1031),
#  ('Ziel', 1027),
#  ('aktuellen', 1026),
#  ('Uhr', 1025),
#  ('Dazu', 1024),
#  ('vielleicht', 1023),
#  ('Zum', 1022),
#  ('Straße', 1022),
#  (',,Ich', 1020),
#  ('ein.', 1019),
#  ('allein', 1011),
#  ('Deutsche', 1010),
#  ('Debatte', 1008),
#  ('Allerdings', 1007),
#  ('bald', 1005),
#  ('sieben', 1005),
#  (',,Das', 1004),
#  ('zeigt', 1001),
#  ('2021', 998),
#  ('zweiten', 998),
#  ('Personen', 997),
#  ('knapp', 997),
#  ('Gesellschaft', 996),
#  ('Bevölkerung', 996),
#  ('Fraktion', 995),
#  ('Schule', 993),
#  ('gute', 992),
#  ('ging', 989),
#  ('einigen', 988),
#  ('September', 987),
#  ('Nicht', 987),
#  ('Coronakrise', 986),
#  ('überhaupt', 985),
#  ('Abstand', 984),
#  ('Sprecher', 981),
#  ('Außerdem', 978),
#  ('solle', 973),
#  ('gehört', 972),
#  ('Bis', 971),
#  ('Stadtrat', 970),
#  ('daher', 969),
#  ('angesichts', 969),
#  ('Christian', 968),
#  ('Öffnung', 966),
#  ('offenbar', 965),
#  ('worden,', 963),
#  ('Stimmen', 963),
#  ('erklärt', 963),
#  ('jeden', 961),
#  ('halten', 960),
#  ('Scholz', 959),
#  ('Donald', 958),
#  ('Angaben', 953),
#  ('eben', 952),
#  ('Mitglieder', 951),
#  ('kann,', 950),
#  ('auch,', 949),
#  ('geben.', 946),
#  ('Nur', 946),
#  ('fordert', 941),
#  ('Während', 940),
#  ('wirklich', 939),
#  ('Monate', 939),
#  ('wurde,', 936),
#  ('Leute', 935),
#  ('hatte,', 934),
#  ('Frau', 933),
#  ('zufolge', 930),
#  ('Entwicklung', 925),
#  ('Alle', 924),
#  ('Koalition', 923),
#  ('Kitas', 920),
#  ('Art', 919),
#  ('15', 917),
#  ('Italien', 916),
#  ('Haus', 915),
#  ('mehrere', 915),
#  ('europäischen', 915),
#  ('Kampf', 912),
#  ('Ob', 912),
#  ('stellt', 909),
#  ('mit.', 908),
#  ('brauchen', 908),
#  ('tatsächlich', 907),
#  ('statt', 905),
#  ('Juli', 904),
#  ('"Wir', 901),
#  ('eigene', 899),
#  ('Zeitung', 895),
#  ('Landesregierung', 893),
#  ('Behörden', 892),
#  ('Gesetz', 891),
#  ('Konzept', 886),
#  ('gleich', 882),
#  ('Parteien', 880),
#  ('teilte', 879),
#  ('Regeln', 878),
#  ('Rolle', 878),
#  ('Demonstranten', 878),
#  ('schwer', 874),
#  ('Schon', 874),
#  ('Hilfe', 874),
#  ('Dort', 872),
#  ('machen.', 869),
#  ('wolle', 867),
#  ('Jetzt', 867),
#  ('Deshalb', 865),
#  ('ebenso', 863),
#  ('hieß', 861),
#  ('Grenzen', 861),
#  ('NRW', 861),
#  ('je', 860),
#  ('dafür,', 857),
#  ('acht', 857),
#  ('müssen,', 856),
#  ('lang', 855),
#  ('Höhe', 853),
#  ('Medien', 851),
#  ('Mann', 850),
#  ('darauf,', 850),
#  ('auf.', 850),
#  (',,Es', 849),
#  ('sonst', 847),
#  ('findet', 847),
#  ('Zahlen', 846),
#  ('–', 843),
#  ('Kandidaten', 843),
#  ('Weil', 840),
#  ('konnte', 840),
#  ('Recht', 839),
#  ('Vorschlag', 839),
#  ('innerhalb', 839),
#  ('Menschen,', 834),
#  ('Schritt', 833),
#  ('Hause', 831),
#  ('lassen', 830),
#  ('ein,', 829),
#  ('Noch', 827),
#  ('gehe', 826),
#  ('ohnehin', 826),
#  ('"Die', 821),
#  ('Entscheidungen', 821),
#  ('Familien', 818),
#  ('Frage,', 813),
#  ('gemacht', 813),
#  ('habe.', 812),
#  ('Ort', 812),
#  ('Lufthansa', 810),
#  ('Gespräch', 806),
#  ('Problem', 806),
#  ('Wochenende', 802),
#  ('2018', 799),
#  ('daran', 799),
#  ('Ministerpräsidenten', 796),
#  ('Prozent.', 793),
#  ('obwohl', 792),
#  ('40', 790),
#  ('spricht', 789),
#  ('paar', 786),
#  ('sprach', 783),
#  ('aktuell', 782),
#  ('Samstag', 781),
#  ('kurz', 780),
#  ('gewesen', 779),
#  ('kleinen', 772),
#  ('erneut', 772),
#  ('aufgrund', 765),
#  ('schließlich', 765),
#  ('möglichst', 764),
#  ('gewesen,', 763),
#  ('klar', 763),
#  ('Düsseldorf', 762),
#  ('Geschichte', 759),
#  ('Jahres', 758),
#  ('zweite', 755),
#  ('Grund', 754),
#  ('sozialen', 754),
#  ('Laut', 753),
#  ('Sommer', 753),
#  ('Verfügung', 752),
#  ('ganze', 750),
#  ('Laschet', 747),
#  ('Schutz', 745),
#  ('jede', 739),
#  ('\x84Die', 736),
#  ('längst', 735),
#  ('gerne', 732),
#  ('Informationen', 732),
#  ('Landes', 731),
#  ('länger', 730),
#  ('wirtschaftlichen', 730),
#  ('Druck', 729),
#  ('sicher', 727),
#  ('Januar', 726),
#  ('Hälfte', 726),
#  ('soll,', 724),
#  ('Sicherheit', 724),
#  ('Verantwortung', 723),
#  ('Kunden', 722),
#  ('Demokratie', 719),
#  ('schrieb', 719),
#  ('beispielsweise', 719),
#  ('Bereich', 719),
#  ('Rat', 718),
#  ('Trumps', 717),
#  ('ab,', 717),
#  ('musste', 716),
#  ('Proteste', 715),
#  ('Ihre', 714),
#  ('solchen', 713),
#  ('sie.', 712),
#  ('finden', 712),
#  ('Kindern', 710),
#  ('Einschränkungen', 709),
#  ('seines', 709),
#  ('größte', 708),
#  ('jeweils', 706),
#  ('scheint', 705),
#  ('geben,', 705),
#  ('wollen.', 703),
#  ('Dafür', 703),
#  ('öffentliche', 702),
#  ('Probleme', 701),
#  ('Kommunalwahl', 701),
#  ('machen,', 700),
#  ('Präsidenten', 698),
#  ('Familie', 696),
#  ('möchte', 695),
#  ('Streit', 694),
#  ('warum', 694),
#  ('Vorsitzende', 694),
#  ('Betrieb', 692),
#  ('Sonntag', 692),
#  ('Über', 691),
#  ('sich,', 691),
#  ('Europäischen', 690),
#  ('größten', 689),
#  ('nachdem', 689),
#  ('Einsatz', 689),
#  ('öffnen', 688),
#  ('Rahmen', 688),
#  ('Hier', 688),
#  ('all', 688),
#  ('zusammen', 687),
#  ('14', 685),
#  ('15.', 685),
#  ('setzt', 684),
#  ('Frankreich', 684),
#  ('kündigte', 684),
#  ('tun', 682),
#  ('Covid-19', 681),
#  ('Urteil', 681),
#  ('arbeiten', 679),
#  ('Masken', 677),
#  ('Chef', 676),
#  ('anderer', 675),
#  ('60', 675),
#  ('zurück.', 675),
#  ('Tod', 675),
#  ('Frauen', 675),
#  ('durchaus', 674),
#  ('Plan', 674),
#  ('Seiten', 673),
#  ('kleine', 670),
#  ('könnte.', 670),
#  ('16', 669),
#  ('Gruppe', 666),
#  ('Mitglied', 666),
#  ('Dieser', 666),
#  ('wären', 665),
#  ('neun', 663),
#  ('Vertreter', 663),
#  ('Unter', 663),
#  ('seien.', 663),
#  ('25', 661),
#  ('Parlament', 661),
#  ('bleiben.', 660),
#  ('schreibt', 656),
#  ('gelten', 656),
#  ('fordern', 656),
#  ('endlich', 656),
#  ('darum,', 655),
#  ('Zwar', 655),
#  ('erhalten', 652),
#  ('sollen.', 652),
#  ('machte', 652),
#  ('Erst', 652),
#  ('niemand', 652),
#  ('Aachen', 651),
#  ('Umgang', 650),
#  ('direkt', 650),
#  ('Ihr', 647),
#  ('Freien', 647),
#  ('richtig', 646),
#  ('Herbst', 645),
#  ('EZB', 644),
#  ('Stefan', 643),
#  ('habe,', 642),
#  ('werde.', 640),
#  ('Hongkong', 638),
#  ('Hilfen', 638),
#  ('forderte', 637),
#  ('stärker', 636),
#  ('kommen.', 636),
#  ('18', 636),
#  ('nächste', 635),
#  ('will,', 635),
#  ('Bundeskanzlerin', 635),
#  ('Polizisten', 635),
#  ('Experten', 634),
#  ('Stunden', 634),
#  ('Tests', 632),
#  ('wichtige', 631),
#  ('großer', 629),
#  ('geplanten', 629),
#  ('Zusammenarbeit', 628),
#  ('wichtig', 627),
#  ('stellen', 627),
#  ('EU-Kommission', 627),
#  ('führt', 626),
#  ('politisch', 626),
#  ('Martin', 626),
#  ('Seine', 625),
#  ('Lösung', 624),
#  ('beide', 624),
#  ('er,', 623),
#  ('weder', 622),
#  ('Landkreis', 622),
#  ('könnten.', 620),
#  ('lassen,', 620),
#  ('gemeinsamen', 620),
#  ('500', 620),
#  ('Gefahr', 619),
#  ('Branche', 618),
#  ('zu.', 617),
#  ('Februar', 616),
#  ('braucht', 616),
#  ('weiß', 615),
#  ('Twitter', 615),
#  ('hingegen', 614),
#  ('völlig', 614),
#  ('erstmals', 613),
#  ('bekannt', 613),
#  ('wenige', 613),
#  ('hin', 611),
#  ('gewesen.', 611),
#  ('Saison', 611),
#  ('Pläne', 610),
#  ('Daten', 610),
#  ('darunter', 610),
#  ('europäische', 609),
#  ('betonte', 608),
#  ('Wolfgang', 608),
#  ('Kommission', 607),
#  ('zwölf', 607),
#  ('unser', 606),
#  ('Rathaus', 605),
#  ('Vergleich', 604),
#  ('jedes', 604),
#  ('jedem', 603),
#  ('ließ', 603),
#  ('Brief', 602),
#  ('Auflagen', 602),
#  ('wollen,', 602),
#  ('Ergebnis', 602),
#  ('bekommen', 601),
#  ('sagte,', 601),
#  ('Richtung', 599),
#  ('Washington', 599),
#  ('nehmen', 599),
#  ('dennoch', 598),
#  ('Sache', 596),
#  ('sogenannten', 596),
#  ('Projekt', 596),
#  ('Russland', 595),
#  ('bevor', 594),
#  ('80', 593),
#  ('hohen', 593),
#  ('Wähler', 593),
#  ('Grüne', 593),
#  ('Gericht', 592),
#  ('insbesondere', 590),
#  ('Dem', 589),
#  ('Themen', 589),
#  ('Peking', 589),
#  ('Zeit,', 589),
#  ('Maskenpflicht', 588),
#  ('lediglich', 588),
#  ('stellte', 588),
#  ('Wort', 587),
#  ('Brüssel', 587),
#  ('hoch', 587),
#  ('jedenfalls', 587),
#  ('2017', 585),
#  ('Kurzarbeit', 585),
#  ('hohe', 584),
#  ('gleichzeitig', 583),
#  ('Meter', 583),
#  ('hinaus', 583),
#  ('.', 582),
#  ('Rede', 581),
#  ('Kontakt', 581),
#  ('wissen,', 580),
#  ('Bedingungen', 580),
#  ('geplante', 578),
#  ('geschlossen', 578),
#  ('Liga', 578),
#  ('müsste', 576),
#  ('US-Präsident', 576),
#  ('Diskussion', 575),
#  ('klar,', 574),
#  ('trotzdem', 573),
#  ('Firmen', 573),
#  ('alten', 572),
#  ('würden.', 572),
#  ('Warum', 571),
#  ('daran,', 571),
#  ('Region', 571),
#  ('ihres', 570),
#  ('Richter', 569),
#  ('Fälle', 569),
#  ('Namen', 568),
#  ('wichtig,', 568),
#  ('Polen', 568),
#  ('Investitionen', 567),
#  ('Antwort', 567),
#  ('wenigen', 565),
#  ('Gremium', 564),
#  ('genug', 563),
#  ('liegen', 563),
#  ('Vorsitzender', 562),
#  ('Sein', 561),
#  ('nämlich', 560),
#  ('Vorgehen', 560),
#  ('Olaf', 558),
#  ('öffentlich', 557),
#  ('wurden.', 557),
#  ('dürften', 557),
#  ('berichtet', 557),
#  ('guten', 557),
#  ('Wahlkampf', 557),
#  ('Rassismus', 555),
#  ('gibt,', 555),
#  ('Programm', 555),
#  ('Form', 555),
#  ('Gesundheit', 554),
#  ('Beschluss', 554),
#  ('dringend', 552),
#  ('Fraktionen', 552),
#  ('teilweise', 551),
#  ('gewählt', 550),
#  ('Öffentlichkeit', 550),
#  ('das,', 549),
#  ('sofort', 549),
#  ('Floyd', 548),
#  ('Moment', 548),
#  ('Kollegen', 548),
#  ('gehen.', 548),
#  ('soziale', 547),
#  ('gehören', 547),
#  ('Grenze', 546),
#  ('danach', 546),
#  ('Kraft', 546),
#  ('Mittel', 545),
#  ('weiter.', 544),
#  ('Meinung', 544),
#  ('Biden', 543),
#  ('mehreren', 542),
#  ('kommen,', 542),
#  ('August', 542),
#  ('wiederum', 542),
#  ('bisherigen', 541),
#  ('wann', 541),
#  ('Quarantäne', 540)]

# %% [markdown]
# Result: There are several formatting errors. As a result, strings like "\xa96" are very common.

# %%
#import ftfy to fix formatting errors
import ftfy

#define function to clean the text with 
def fixtext(string):
    return ftfy.fix_text(string)

#apply function
df["Article"] = df["Article"].apply(fixtext)

#check if it worked 
df[df['Article'].str.contains("\xa96")]
# Out:
# Empty DataFrame
# Columns: [ID, Newspaper, Date, Length, Category, Author, Headline, Teaser, Article, Modality, url]
# Index: []

# %% [markdown]
# Result: It seems like it have worked. I tried this not only with this, but also with some other strings.
# There are however still some other issues that I noticed while manually exploring some of the articles (not included in this Notebook for simplicity). For example, Articles from "Der Tagesspiegel" often include a graphic and its title at the end. Issues like this are addressed in the following.

# %%
#remove everything after and including "Graphic" -> removes pictures and their headings from Tagesspiegel articles
def removegraphic(string):
    return string.split("Graphic")[0].strip()
#explore how pervailing this issue is
print(len(df[df['Article'].str.contains("Graphic")]))

df["Article"] = df["Article"].apply(removegraphic)

#see if the code worked
print(len(df[df['Article'].str.contains("Graphic")]))
# Out:
# 3284
# 0

# %% [markdown]
# There are also some more formatting errors that ftfy did not capture. They are addressed in the following.

# %%
#removes the \xa0 string from the text
def reformat(string):
    return string.replace("\xa0", " ")

#see how prevailing this issue is
print(len(df[df['Article'].str.contains("\xa0")]))

#apply the function
df["Article"] = df["Article"].apply(reformat)

#see if it worked
print(len(df[df['Article'].str.contains("\xa0")]))
# Out:
# 56
# 0

# %%
#removes the \xa0 string from the text
def reformat2(string):
    return string.replace("\xad", " ")

#see how prevailing this issue is
print(len(df[df['Article'].str.contains("\xad")]))

#apply the function
df["Article"] = df["Article"].apply(reformat2)

#see if it worked
print(len(df[df['Article'].str.contains("\xad")]))
# Out:
# 408
# 0

# %%
#removes all instances of the \' string from the text. This string denotes the German genitive endinng
#This ending is not important for any of the following analysis an might impede readability metrics
def reformat3(string):
    return string.replace("\'", " ")

#see how prevailing this issue is
print(len(df[df['Article'].str.contains("\'")]))

#apply the function
df["Article"] = df["Article"].apply(reformat3)

#see if it worked
print(len(df[df['Article'].str.contains("\'")]))
# Out:
# 3960
# 0

# %%
#replaces three spaces with just one
def reformat4(string):
    return string.replace("   ", " ")

#see how prevailing this issue is
print(len(df[df['Article'].str.contains("   ")]))

#apply the function
df["Article"] = df["Article"].apply(reformat4)

#see if it worked
print(len(df[df['Article'].str.contains("   ")]))
# Out:
# 3265
# 11

# %%
#replaces dpa which is often named as a source at the end of an article
def reformat5(string):
    return string.replace("dpa", "")

#see how prevailing this issue is
print(len(df[df['Article'].str.contains("dpa")]))

#apply the function
df["Article"] = df["Article"].apply(reformat5)

#see if it worked
print(len(df[df['Article'].str.contains("dpa")]))
# Out:
# 969
# 0

# %%
#replaces fullstops with a fullstop followed by a space in order to avoid confounds of the readability meausure
def reformat6(string):
    return string.replace(".", ". ")

#apply the function
df["Article"] = df["Article"].apply(reformat6)

#replace double spaces with single spaces - this way this operation only affected the cases where a fullstop was not followed by a space
def reformat7(string):
    return string.replace("  ", " ")

#apply the function
df["Article"] = df["Article"].apply(reformat7)

# %%
df.head(5)
# Out:
#         ID                    Newspaper                 Date  Length Category  \
# 6   100006  sueddeutschet politik (www)  2020-05-28T15:34:08       0      nan
# 8   100008  sueddeutschet politik (www)  2020-05-28T17:01:43       0      nan
# 21  100021               die welt (www)  2020-05-28T17:49:45       0  Politik
# 24  100024       aachener zeitung (www)  2020-05-28T03:01:52       0  Politik
# 28  100028  sueddeutschet politik (www)  2020-05-28T03:12:25       0      nan
#
#    Author                                           Headline  \
# 6          SZ Espresso: Nachrichten kompakt - die Übersic...
# 8                               Kommunalpolitik: Abgeblendet
# 21               Wie Söder es schaffte, die AfD zu halbieren
# 24         Länder planen Öffnung: Streit über Schulen und...
# 28           Mecklenburg-Vorpommern: Grundgesetz als Maßstab
#
#                                                Teaser  \
# 6   <p>Was heute wichtig war - und was Sie auf SZ....
# 8                 <p>Bayreuths Stadtrat im Stream</p>
# 21  Die Corona-Krise lässt die CSU erstarken und b...
# 24  <img src="https://www.aachener-zeitung.de/imgs...
# 28  <img src="https://media-cdn.sueddeutsche.de/im...
#
#                                               Article Modality  \
# 6   Das Wichtigste zum Coronavirus. Berufstätige M...   online
# 8   Livestream aus dem Stadtrat, das klingt transp...   online
# 21                                                nan   online
# 24  Der Streit über die Wiederöffnung von Schulen ...   online
# 28  An diesem Donnerstag trifft sich das neue Land...   online
#
#                                                   url
# 6   https://www.sueddeutsche.de/politik/nachrichte...
# 8   https://www.sueddeutsche.de/bayern/kommunalpol...
# 21  https://www.welt.de/politik/deutschland/plus20...
# 24  https://www.aachener-zeitung.de/politik/deutsc...
# 28  https://www.sueddeutsche.de/politik/barbara-bo...

# %%
df["Article"][6]
# Out:
# 6    Das Wichtigste zum Coronavirus. Berufstätige M...
# 6    Wenn jeder nur an sich denkt, dann ist ja an a...
# Name: Article, dtype: object

# %% [markdown]
# #### h) Update article length

# %%
#function that counts the number of words in articles
def count_words(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    tokens_no_punctuation = []
    punctuation = [",", ".", ":", "!", "?", "'", ",", "  ", ")", "(", "-", '"', "   ", ";", "»", "«", "'", "/"]
    for w in tokens:
        if w not in punctuation:
            tokens_no_punctuation.append(w)
    return len(tokens_no_punctuation)

#apply function to df
df["Length"] = [count_words(text) for text in df["Article"].astype(str)]
                   
#inspect data
df.head(3)
# Out:
#         ID                    Newspaper                 Date  Length Category  \
# 6   100006  sueddeutschet politik (www)  2020-05-28T15:34:08     367      nan
# 8   100008  sueddeutschet politik (www)  2020-05-28T17:01:43     200      nan
# 21  100021               die welt (www)  2020-05-28T17:49:45       1  Politik
#
#    Author                                           Headline  \
# 6          SZ Espresso: Nachrichten kompakt - die Übersic...
# 8                               Kommunalpolitik: Abgeblendet
# 21               Wie Söder es schaffte, die AfD zu halbieren
#
#                                                Teaser  \
# 6   <p>Was heute wichtig war - und was Sie auf SZ....
# 8                 <p>Bayreuths Stadtrat im Stream</p>
# 21  Die Corona-Krise lässt die CSU erstarken und b...
#
#                                               Article Modality  \
# 6   Das Wichtigste zum Coronavirus. Berufstätige M...   online
# 8   Livestream aus dem Stadtrat, das klingt transp...   online
# 21                                                nan   online
#
#                                                   url
# 6   https://www.sueddeutsche.de/politik/nachrichte...
# 8   https://www.sueddeutsche.de/bayern/kommunalpol...
# 21  https://www.welt.de/politik/deutschland/plus20...

# %% [markdown]
# #### i) Remove articles that could not be scraped due to them being behind a paywall

# %%
#check how many articles have fewer than 40 words.
len(df[df["Length"] <40])
# Out:
# 117

# %%
#remove the short articles
df = df[~(df["Length"] <=40)]
#check if the code worked
print(len(df), len(df[df["Length"] <40]))
# Out:
# 11491 0

# %% [markdown]
# ### 2) NLP to stem text and remove stopwords

# %%
from nltk.corpus import stopwords 
stop_words = set(stopwords.words('german')) 
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("german")
from collections import Counter

#function to remove stopwords
def remove_stopwords_and_stem(text):
    #apply SpaCy to tokenise
    doc = nlp(text)
    #create a list of tokens
    tokens = [token.text for token in doc]
    #create an empty list for all words in a text that are not stopwords
    no_stopwords = []
    #loop over the tokens list and append non-stopwords to the no_stopwords list
    for w in tokens: 
        if w not in stop_words: 
            no_stopwords.append(w)
    #stem all words in the list
    stems=""
    for word in no_stopwords:
        stems=stems + stemmer.stem(word) + " "
    #return the final stems as a single string
    return(stems)

# %%
#apply functions in order to...

#... create a column with the cleaned article text (where stopwords are removed and all words are stemmed)
df["clean text"] = [remove_stopwords_and_stem(text) for text in df["Article"]]

#... create a column with the number of words for the cleaned text
df["words in clean text"] = [count_words(text) for text in df["clean text"]]

#inspect data
df.head(3)
# Out:
#         ID                    Newspaper                 Date  Length Category  \
# 6   100006  sueddeutschet politik (www)  2020-05-28T15:34:08     367      nan
# 8   100008  sueddeutschet politik (www)  2020-05-28T17:01:43     200      nan
# 24  100024       aachener zeitung (www)  2020-05-28T03:01:52     512  Politik
#
#    Author                                           Headline  \
# 6          SZ Espresso: Nachrichten kompakt - die Übersic...
# 8                               Kommunalpolitik: Abgeblendet
# 24         Länder planen Öffnung: Streit über Schulen und...
#
#                                                Teaser  \
# 6   <p>Was heute wichtig war - und was Sie auf SZ....
# 8                 <p>Bayreuths Stadtrat im Stream</p>
# 24  <img src="https://www.aachener-zeitung.de/imgs...
#
#                                               Article Modality  \
# 6   Das Wichtigste zum Coronavirus. Berufstätige M...   online
# 8   Livestream aus dem Stadtrat, das klingt transp...   online
# 24  Der Streit über die Wiederöffnung von Schulen ...   online
#
#                                                   url  \
# 6   https://www.sueddeutsche.de/politik/nachrichte...
# 8   https://www.sueddeutsche.de/bayern/kommunalpol...
# 24  https://www.aachener-zeitung.de/politik/deutsc...
#
#                                            clean text  words in clean text
# 6   das wichtig coronavirus . berufstat mutt vat ,...                  224
# 8   livestream stadtrat , klingt transparent erstr...                  104
# 24  der streit wiederoffn schul kindergart kris ve...                  318

# %% [markdown]
# ### 3) Creating dummy variables

# %% [markdown]
# #### a) for reach

# %%
regional = ["Aachener Zeitung", "Rheinische", "Stuttgarter", "aachener", "rheinische, stuttgarter"]
national = ["Tagesspiegel", "tagesspiegel", "Welt", "welt", "Süddeutsche", "süddeutschet"]

def create_reach_dummy(row):
        if row == "Aachener Zeitung" or row == "aachener zeitung (www)" or row == "Stuttgarter Zeitung" or row == "stuttgarter zeitung (www)" or row == "Rheinische Post" or row == "rheinische post (www)":
            return 0
        else:
            return 1

df["reach_dummy"] = [create_reach_dummy(row) for row in df["Newspaper"]]

# %% [markdown]
# #### b) for modality

# %%
cond1 = df.Modality.str.contains("print")
cond2 = df.Modality.str.contains("online")
df["modality_dummy"] = np.where(cond1, 1, np.where(cond2, 0, 2) )

# %% [markdown]
# ### 4) Saving the clean and complete datafile for further analysis

# %%
df.to_excel("complete_data_cleaned.xlsx")

# %% [markdown]
# ### 5) Exploring the data distribution

# %%
df.groupby("Newspaper").count()
# Out:
#                                                 ID  Date  Length  Category  \
# Newspaper
# Aachener Zeitung                               970   963     970       970
# Der Tagesspiegel                              1286  1281    1286      1286
# Die Welt                                       831   831     831       831
# Rheinische Post                               2375  2365    2375      2375
# Stuttgarter Zeitung                           1237  1237    1237      1237
# Süddeutsche Zeitung (inkl. Regionalausgaben)  3720  3708    3720      3720
# aachener zeitung (www)                         168   168     168       168
# der tagesspiegel (www)                         264   264     264       264
# die welt (www)                                 177   177     177       177
# rheinische post (www)                          173   173     173       173
# stuttgarter zeitung (www)                      115   115     115       115
# sueddeutschet politik (www)                    175   175     175       175
#
#                                               Author  Headline  Teaser  \
# Newspaper
# Aachener Zeitung                                 970       970     970
# Der Tagesspiegel                                1286      1286    1286
# Die Welt                                         831       831     831
# Rheinische Post                                 2375      2375    2375
# Stuttgarter Zeitung                             1237      1237    1237
# Süddeutsche Zeitung (inkl. Regionalausgaben)    3720      3720    3720
# aachener zeitung (www)                           168       168     168
# der tagesspiegel (www)                           264       264     264
# die welt (www)                                   177       177     177
# rheinische post (www)                            173       173     173
# stuttgarter zeitung (www)                        115       115     115
# sueddeutschet politik (www)                      175       175     175
#
#                                               Article  Modality   url  \
# Newspaper
# Aachener Zeitung                                  970       970   970
# Der Tagesspiegel                                 1286      1286  1286
# Die Welt                                          831       831   831
# Rheinische Post                                  2375      2375  2375
# Stuttgarter Zeitung                              1237      1237  1237
# Süddeutsche Zeitung (inkl. Regionalausgaben)     3720      3720  3720
# aachener zeitung (www)                            168       168   168
# der tagesspiegel (www)                            264       264   264
# die welt (www)                                    177       177   177
# rheinische post (www)                             173       173   173
# stuttgarter zeitung (www)                         115       115   115
# sueddeutschet politik (www)                       175       175   175
#
#                                               clean text  words in clean text  \
# Newspaper
# Aachener Zeitung                                     970                  970
# Der Tagesspiegel                                    1286                 1286
# Die Welt                                             831                  831
# Rheinische Post                                     2375                 2375
# Stuttgarter Zeitung                                 1237                 1237
# Süddeutsche Zeitung (inkl. Regionalausgaben)        3720                 3720
# aachener zeitung (www)                               168                  168
# der tagesspiegel (www)                               264                  264
# die welt (www)                                       177                  177
# rheinische post (www)                                173                  173
# stuttgarter zeitung (www)                            115                  115
# sueddeutschet politik (www)                          175                  175
#
#                                               reach_dummy  modality_dummy
# Newspaper
# Aachener Zeitung                                      970             970
# Der Tagesspiegel                                     1286            1286
# Die Welt                                              831             831
# Rheinische Post                                      2375            2375
# Stuttgarter Zeitung                                  1237            1237
# Süddeutsche Zeitung (inkl. Regionalausgaben)         3720            3720
# aachener zeitung (www)                                168             168
# der tagesspiegel (www)                                264             264
# die welt (www)                                        177             177
# rheinische post (www)                                 173             173
# stuttgarter zeitung (www)                             115             115
# sueddeutschet politik (www)                           175             175

# %%
len(df)
# Out:
# 11491
