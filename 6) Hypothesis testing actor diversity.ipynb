# %% [markdown]
# # Hypothesis testing: Impartiality
#
# In this Notebook, the impartiality data is explored and the related hypotheses are (partially) tested.

# %% [markdown]
# ## Loading packages and data

# %%
#import the necessary packages
import pandas as pd
from pandas import read_excel
from scipy import stats
from scipy.stats import mannwhitneyu

# %%
#read and inspect the data
df = read_excel("complete_data_cleaned_with_impartiality.xlsx")
df.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1      ID                    Newspaper  \
# 0           0             6  100006  sueddeutschet politik (www)
# 1           1             8  100008  sueddeutschet politik (www)
# 2           2            24  100024       aachener zeitung (www)
#
#                   Date  Length Category Author  \
# 0  2020-05-28T15:34:08     367      NaN    NaN
# 1  2020-05-28T17:01:43     200      NaN    NaN
# 2  2020-05-28T03:01:52     512  Politik    NaN
#
#                                             Headline  \
# 0  SZ Espresso: Nachrichten kompakt - die Übersic...
# 1                       Kommunalpolitik: Abgeblendet
# 2  Länder planen Öffnung: Streit über Schulen und...
#
#                                               Teaser  ... Modality  \
# 0  <p>Was heute wichtig war - und was Sie auf SZ....  ...   online
# 1                <p>Bayreuths Stadtrat im Stream</p>  ...   online
# 2  <img src="https://www.aachener-zeitung.de/imgs...  ...   online
#
#                                                  url  \
# 0  https://www.sueddeutsche.de/politik/nachrichte...
# 1  https://www.sueddeutsche.de/bayern/kommunalpol...
# 2  https://www.aachener-zeitung.de/politik/deutsc...
#
#                                           clean text words in clean text  \
# 0  das wichtig coronavirus . berufstat mutt vat ,...                 224
# 1  livestream stadtrat , klingt transparent erstr...                 104
# 2  der streit wiederoffn schul kindergart kris ve...                 318
#
#    reach_dummy  modality_dummy  neutrality dummy  balance of actors dummy  \
# 0            1               0                 1                        0
# 1            1               0                 1                        1
# 2            0               0                 1                        0
#
#    balance of viewpoints dummy  impartiality
# 0                            1             2
# 1                            0             2
# 2                            1             2
#
# [3 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'ID', 'Newspaper', 'Date', 'Length',
#        'Category', 'Author', 'Headline', 'Teaser', 'Article', 'Modality',
#        'url', 'clean text', 'words in clean text', 'reach_dummy',
#        'modality_dummy', 'neutrality dummy', 'balance of actors dummy',
#        'balance of viewpoints dummy', 'impartiality'],
#       dtype='object')

# %% [markdown]
# ## Select relevant columns

# %%
df = df[["ID", "Newspaper", "Length", "Article", "modality_dummy", "reach_dummy", "clean text", 
         "neutrality dummy", "balance of actors dummy", "balance of viewpoints dummy", "impartiality"]]
len(df)
# Out:
# 11491

# %% [markdown]
# ## Descriptives

# %%
print("Overall sample")
print(df["impartiality"].mean())
print(df["impartiality"].std())
# Out:
# Overall sample
# 1.3869114959533548
# 0.798812842452084

# %%
print("Print sample")
print(df[df["modality_dummy"] == 1]["impartiality"].mean())
print(df[df["modality_dummy"] == 1]["impartiality"].std())
print("")
print("Online sample")
print(df[df["modality_dummy"] == 0]["impartiality"].mean())
print(df[df["modality_dummy"] == 0]["impartiality"].std())
# Out:
# Print sample
# 1.3879451002975334
# 0.7979820672125785
#
# Online sample
# 1.376865671641791
# 0.8071495815058273

# %%
print("National sample")
print(df[df["reach_dummy"] == 1]["impartiality"].mean())
print(df[df["reach_dummy"] == 1]["impartiality"].std())
print("")
print("Regional sample")
print(df[df["reach_dummy"] == 0]["impartiality"].mean())
print(df[df["reach_dummy"] == 0]["impartiality"].std())
# Out:
# National sample
# 1.3041995970866265
# 0.8096841200677771
#
# Regional sample
# 1.4928543072647875
# 0.7719063025374823

# %% [markdown]
# ## Hypothesis test

# %%
print("RQ3a: Reach")
print(mannwhitneyu(df[df["reach_dummy"] == 1]["impartiality"], df[df["reach_dummy"] == 0]["impartiality"]))
# Out:
# RQ3a: Reach
# MannwhitneyuResult(statistic=14138917.5, pvalue=2.382451200871224e-38)

# %%
print("RQ3b: Modality")
print(mannwhitneyu(df[df["modality_dummy"] == 1]["impartiality"], df[df["modality_dummy"] == 0]["impartiality"]))
# Out:
# RQ3b: Modality
# MannwhitneyuResult(statistic=5532931.5, pvalue=0.29563392256831444)

# %% [markdown]
# ## Comparisons

# %%
df[["Newspaper", "neutrality dummy", "balance of actors dummy", "balance of viewpoints dummy", "impartiality"]].groupby("Newspaper").mean()
# Out:
#                                               neutrality dummy  \
# Newspaper
# Aachener Zeitung                                      0.586598
# Der Tagesspiegel                                      0.462675
# Die Welt                                              0.216606
# Rheinische Post                                       0.616000
# Stuttgarter Zeitung                                   0.586904
# Süddeutsche Zeitung (inkl. Regionalausgaben)          0.428226
# aachener zeitung (www)                                0.595238
# der tagesspiegel (www)                                0.390152
# die welt (www)                                        0.440678
# rheinische post (www)                                 0.710983
# stuttgarter zeitung (www)                             0.817391
# sueddeutschet politik (www)                           0.502857
#
#                                               balance of actors dummy  \
# Newspaper
# Aachener Zeitung                                             0.286598
# Der Tagesspiegel                                             0.250389
# Die Welt                                                     0.268351
# Rheinische Post                                              0.227789
# Stuttgarter Zeitung                                          0.264349
# Süddeutsche Zeitung (inkl. Regionalausgaben)                 0.295699
# aachener zeitung (www)                                       0.345238
# der tagesspiegel (www)                                       0.204545
# die welt (www)                                               0.293785
# rheinische post (www)                                        0.248555
# stuttgarter zeitung (www)                                    0.260870
# sueddeutschet politik (www)                                  0.302857
#
#                                               balance of viewpoints dummy  \
# Newspaper
# Aachener Zeitung                                                 0.611340
# Der Tagesspiegel                                                 0.646190
# Die Welt                                                         0.593261
# Rheinische Post                                                  0.663579
# Stuttgarter Zeitung                                              0.599838
# Süddeutsche Zeitung (inkl. Regionalausgaben)                     0.620699
# aachener zeitung (www)                                           0.523810
# der tagesspiegel (www)                                           0.537879
# die welt (www)                                                   0.564972
# rheinische post (www)                                            0.653179
# stuttgarter zeitung (www)                                        0.495652
# sueddeutschet politik (www)                                      0.571429
#
#                                               impartiality
# Newspaper
# Aachener Zeitung                                  1.484536
# Der Tagesspiegel                                  1.359253
# Die Welt                                          1.078219
# Rheinische Post                                   1.507368
# Stuttgarter Zeitung                               1.451091
# Süddeutsche Zeitung (inkl. Regionalausgaben)      1.344624
# aachener zeitung (www)                            1.464286
# der tagesspiegel (www)                            1.132576
# die welt (www)                                    1.299435
# rheinische post (www)                             1.612717
# stuttgarter zeitung (www)                         1.573913
# sueddeutschet politik (www)                       1.377143

# %%
df[["Newspaper", "neutrality dummy", "balance of actors dummy", "balance of viewpoints dummy", "impartiality"]].groupby("Newspaper").std()
# Out:
#                                               neutrality dummy  \
# Newspaper
# Aachener Zeitung                                      0.492698
# Der Tagesspiegel                                      0.498799
# Die Welt                                              0.412180
# Rheinische Post                                       0.486460
# Stuttgarter Zeitung                                   0.492589
# Süddeutsche Zeitung (inkl. Regionalausgaben)          0.494888
# aachener zeitung (www)                                0.492313
# der tagesspiegel (www)                                0.488711
# die welt (www)                                        0.497877
# rheinische post (www)                                 0.454622
# stuttgarter zeitung (www)                             0.388036
# sueddeutschet politik (www)                           0.501427
#
#                                               balance of actors dummy  \
# Newspaper
# Aachener Zeitung                                             0.452405
# Der Tagesspiegel                                             0.433405
# Die Welt                                                     0.443368
# Rheinische Post                                              0.419494
# Stuttgarter Zeitung                                          0.441164
# Süddeutsche Zeitung (inkl. Regionalausgaben)                 0.456418
# aachener zeitung (www)                                       0.476867
# der tagesspiegel (www)                                       0.404135
# die welt (www)                                               0.456787
# rheinische post (www)                                        0.433430
# stuttgarter zeitung (www)                                    0.441031
# sueddeutschet politik (www)                                  0.460812
#
#                                               balance of viewpoints dummy  \
# Newspaper
# Aachener Zeitung                                                 0.487697
# Der Tagesspiegel                                                 0.478337
# Die Welt                                                         0.491521
# Rheinische Post                                                  0.472584
# Stuttgarter Zeitung                                              0.490129
# Süddeutsche Zeitung (inkl. Regionalausgaben)                     0.485278
# aachener zeitung (www)                                           0.500926
# der tagesspiegel (www)                                           0.499510
# die welt (www)                                                   0.497167
# rheinische post (www)                                            0.477340
# stuttgarter zeitung (www)                                        0.502169
# sueddeutschet politik (www)                                      0.496292
#
#                                               impartiality
# Newspaper
# Aachener Zeitung                                  0.773842
# Der Tagesspiegel                                  0.808527
# Die Welt                                          0.760402
# Rheinische Post                                   0.771114
# Stuttgarter Zeitung                               0.776001
# Süddeutsche Zeitung (inkl. Regionalausgaben)      0.810358
# aachener zeitung (www)                            0.795894
# der tagesspiegel (www)                            0.795328
# die welt (www)                                    0.822724
# rheinische post (www)                             0.727580
# stuttgarter zeitung (www)                         0.738192
# sueddeutschet politik (www)                       0.834282

# %% [markdown]
# ## Means and standard deviations

# %%
print("AZ")
print(df[(df["Newspaper"]== "Aachener Zeitung") | (df["Newspaper"]== "aachener zeitung (www)")]["impartiality"].mean())
print(df[(df["Newspaper"]== "Aachener Zeitung") | (df["Newspaper"]== "aachener zeitung (www)")]["impartiality"].std())
print("RP")
print(df[(df["Newspaper"]== "Rheinische Post") | (df["Newspaper"]== "rheinische post (www)")]["impartiality"].mean())
print(df[(df["Newspaper"]== "Rheinische Post") | (df["Newspaper"]== "rheinische post (www)")]["impartiality"].std())
print("STZ")
print(df[(df["Newspaper"]== "Stuttgarter Zeitung") | (df["Newspaper"]== "stuttgarter zeitung (www)")]["impartiality"].mean())
print(df[(df["Newspaper"]== "Stuttgarter Zeitung") | (df["Newspaper"]== "stuttgarter zeitung (www)")]["impartiality"].std())
print("Welt")
print(df[(df["Newspaper"]== "Die Welt") | (df["Newspaper"]== "die welt (www)")]["impartiality"].mean())
print(df[(df["Newspaper"]== "Die Welt") | (df["Newspaper"]== "die welt (www)")]["impartiality"].std())
print("TS")
print(df[(df["Newspaper"]== "Der Tagesspiegel") | (df["Newspaper"]== "der tagesspiegel (www)")]["impartiality"].mean())
print(df[(df["Newspaper"]== "Der Tagesspiegel") | (df["Newspaper"]== "der tagesspiegel (www)")]["impartiality"].std())
print("SZ")
print(df[(df["Newspaper"]== "Süddeutsche Zeitung (inkl. Regionalausgaben)") | (df["Newspaper"]== "sueddeutschet politik (www)")]["impartiality"].mean())
print(df[(df["Newspaper"]== "Süddeutsche Zeitung (inkl. Regionalausgaben)") | (df["Newspaper"]== "sueddeutschet politik (www)")]["impartiality"].std())
# Out:
# AZ
# 1.4815465729349737
# 0.7768146842573067
# RP
# 1.5145211930926217
# 0.7685572826816981
# STZ
# 1.4615384615384615
# 0.7733534118563765
# Welt
# 1.117063492063492
# 0.775868996057464
# TS
# 1.3206451612903225
# 0.8105340016774143
# SZ
# 1.3460847240051348
# 0.8113660024574407
