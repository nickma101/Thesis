# %% [markdown]
# # Emotionality & sentiment assessment

# %% [markdown]
# ## Assessing emotionality with SpaCy & NLTK
#
# In this Jupyter notebook, I assess the emotionality of each article, as well as its negativity and positivity (I also included sentiment functions but ended up not using them).
# I do so using two different sentiment dictionaries, in order to have a comparison of sentiment measurements.
# The first sentiment dictionary is taken from the SentiWS corpus. The second is taken from the Rauh sentiment dictionary and, unlike the SentiWS dicitonary, accounts for negations (to an extent).

# %% [markdown]
# The steps that are performed in this notebook are the following:
#
# 1) Loading necessary packages
#
# 2) Loading the cleaned data
#
# 3) Assessing emotionality with the SentiWS corpus
#     - Creating lists of positive and negative words
#     - Creating functions to count positve and negative words
#     - Applying counting functions to get the overall number as well as the ratio of positive and negative words
#     - Calculating overall emotionality
#
# 4) Computing overall article sentiment according to the SentiWS corpus
#     - Creating a sentiment function
#     - Applying the function to the dataframe
#     - Inspecting the data
#
# 5) Assessing emotionality with the Rauh sentiment dictionary
#     - Creating lists of positive and negative words
#     - Creating functions to count positve and negative words
#     - Applying counting functions to get the overall number as well as the ratio of positive and negative words
#     - Calculating overall emotionality
#
# 6) Computing overall article sentiment according to Rauh sentiment dictionary
#     - Creating a sentiment function that accounts for negations
#     - Applying the function to the dataframe
#     - Inspecting the data
#
# 7) Saving the data with the newly created variables

# %% [markdown]
# ### 1) Loading necessary packages

# %%
#import pandas
import pandas as pd
from pandas import read_excel
#import numpy
import numpy as np
#load SpaCy
import spacy
#import German language model
import de_core_news_md
#define nlp pipe
nlp = de_core_news_md.load()

# %% [markdown]
# ### 2) Loading the cleaned data

# %%
df = read_excel("complete_data_cleaned.xlsx")

# %% [markdown]
# ### 3) Assessing emotionality with the SentiWS corpus
#
# #### a) Creating lists of positive and negative words

# %%
#read in the SentiWS text file with positive words
pos = pd.read_csv("SentiWS_v1.8c_Positive.txt",sep='\t', names=["word", "value", "forms"])
#clean the text file
pos[['word','wordtype']] = pos.word.str.split("|",expand=True) 
#create list of positive words (empty for now)
pos_list = []
#loop over the df in order to create a list with all positive words
for e in pos["word"]:
    pos_list.append(e)

# %%
#same as above
neg = pd.read_csv("SentiWS_v1.8c_Negative.txt",sep='\t', names=["word", "value", "forms"])
neg[['word','wordtype']] = neg.word.str.split("|",expand=True) 
neg_list = []
for e in neg["word"]:
    neg_list.append(e)

# %% [markdown]
# #### b) Creating functions to count positve and negative words

# %%
#function to detect positive words
def count_positivewords(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    poscount = 0
    for w in tokens:
        if w in pos_list:
            poscount+=1
    return poscount

#function to detect negative words
def count_negativewords(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    negcount = 0
    for w in tokens:
        if w in neg_list:
            negcount+=1
    return negcount

# %% [markdown]
# #### c) Applying counting functions to get the overall number as well as the ratio of positive and negative words

# %%
#apply functions in order to...

#... create a column with the number of positive words
df["positive words"] = [count_positivewords(text) for text in df["clean text"]]

#... create a column with the number of negative words
df["negative words"] = [count_negativewords(text) for text in df["clean text"]]

# %%
#creating a new column for overall emotionality (percenage of overall words that are negative)
df["negativity ratio"] = df["negative words"]/df["words in clean text"]
#creating a new column for overall emotionality (percenage of overall words that are positve)
df["positivity ratio"] = df["positive words"]/df["words in clean text"]

# %% [markdown]
# #### d) Use the number of positive and negative words per article to calculate overall emotionality

# %%
#creating a new column for overall emotionality 
df["emotionality"] = (df["negative words"]+df["positive words"])
#creating a new column for overall emotionality ratio (percenage of overall words that are positve or negative)
df["emotionality ratio"] = (df["negative words"]+df["positive words"])/df["words in clean text"]

# %%
#inspect data
df.head(3)
# Out:
#    Unnamed: 0      ID                    Newspaper                 Date  \
# 0           6  100006  sueddeutschet politik (www)  2020-05-28T15:34:08
# 1           8  100008  sueddeutschet politik (www)  2020-05-28T17:01:43
# 2          24  100024       aachener zeitung (www)  2020-05-28T03:01:52
#
#    Length Category Author                                           Headline  \
# 0     367      NaN    NaN  SZ Espresso: Nachrichten kompakt - die Übersic...
# 1     200      NaN    NaN                       Kommunalpolitik: Abgeblendet
# 2     512  Politik    NaN  Länder planen Öffnung: Streit über Schulen und...
#
#                                               Teaser  \
# 0  <p>Was heute wichtig war - und was Sie auf SZ....
# 1                <p>Bayreuths Stadtrat im Stream</p>
# 2  <img src="https://www.aachener-zeitung.de/imgs...
#
#                                              Article  ...  \
# 0  Das Wichtigste zum Coronavirus. Berufstätige M...  ...
# 1  Livestream aus dem Stadtrat, das klingt transp...  ...
# 2  Der Streit über die Wiederöffnung von Schulen ...  ...
#
#                                           clean text words in clean text  \
# 0  das wichtig coronavirus . berufstat mutt vat ,...                 224
# 1  livestream stadtrat , klingt transparent erstr...                 104
# 2  der streit wiederoffn schul kindergart kris ve...                 318
#
#   reach_dummy  modality_dummy  positive words  negative words  \
# 0           1               0               8               6
# 1           1               0               2               0
# 2           0               0              11               6
#
#    negativity ratio  positivity ratio  emotionality  emotionality ratio
# 0          0.026786          0.035714            14            0.062500
# 1          0.000000          0.019231             2            0.019231
# 2          0.018868          0.034591            17            0.053459
#
# [3 rows x 22 columns]

# %% [markdown]
# ### 4) Computing overall article sentiment according to the SentiWS corpus
#
# #### a) Creating a sentiment function

# %%
def compute_sentiment(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    word_list = []
    for e in tokens:
        if e in pos_list:
            word_list.append(e)
        elif e in neg_list:
            word_list.append(e)
    df1 = pos[pos['word'].isin(word_list)]
    df2 = neg[neg['word'].isin(word_list)]
    dfs = [df1, df2]
    df_final = pd.concat(dfs)
    sentimentscore = df_final["value"].sum()
    return sentimentscore

# %% [markdown]
# #### b) Applying the function to the dataframe

# %%
#first a function for the overall sentiment score
df["sentimentscore"] = [compute_sentiment(text) for text in df["clean text"]]
#then calculate a ratio to account for article length
df["sentimentscore ratio"] = df["sentimentscore"]/df["words in clean text"]

# %% [markdown]
# #### c) Data overview

# %%
#overview of how many articles are in the dataset
df.groupby("Newspaper").count()
# Out:
#                                               Unnamed: 0    ID  Date  Length  \
# Newspaper
# Aachener Zeitung                                     970   970   963     970
# Der Tagesspiegel                                    1286  1286  1281    1286
# Die Welt                                             831   831   831     831
# Rheinische Post                                     2375  2375  2365    2375
# Stuttgarter Zeitung                                 1237  1237  1237    1237
# Süddeutsche Zeitung (inkl. Regionalausgaben)        3720  3720  3708    3720
# aachener zeitung (www)                               168   168   168     168
# der tagesspiegel (www)                               264   264   264     264
# die welt (www)                                       177   177   177     177
# rheinische post (www)                                173   173   173     173
# stuttgarter zeitung (www)                            115   115   115     115
# sueddeutschet politik (www)                          175   175   175     175
#
#                                               Category  Author  Headline  \
# Newspaper
# Aachener Zeitung                                   970       0       970
# Der Tagesspiegel                                  1286     397      1286
# Die Welt                                           831     657       831
# Rheinische Post                                   2375    1384      2375
# Stuttgarter Zeitung                               1237    1111      1237
# Süddeutsche Zeitung (inkl. Regionalausgaben)      3720    3613      3720
# aachener zeitung (www)                             168       0       168
# der tagesspiegel (www)                             264       0       264
# die welt (www)                                     177       0       177
# rheinische post (www)                              173       0       173
# stuttgarter zeitung (www)                          115       0       115
# sueddeutschet politik (www)                         11       0       175
#
#                                               Teaser  Article  Modality  ...  \
# Newspaper                                                                ...
# Aachener Zeitung                                   0      970       970  ...
# Der Tagesspiegel                                   0     1286      1286  ...
# Die Welt                                           0      831       831  ...
# Rheinische Post                                    0     2375      2375  ...
# Stuttgarter Zeitung                                0     1237      1237  ...
# Süddeutsche Zeitung (inkl. Regionalausgaben)       0     3720      3720  ...
# aachener zeitung (www)                           168      168       168  ...
# der tagesspiegel (www)                           264      264       264  ...
# die welt (www)                                   177      177       177  ...
# rheinische post (www)                            173      173       173  ...
# stuttgarter zeitung (www)                        115      115       115  ...
# sueddeutschet politik (www)                      175      175       175  ...
#
#                                               clean text  words in clean text  \
# Newspaper
# Aachener Zeitung                                     970                  970
# Der Tagesspiegel                                    1286                 1286
# Die Welt                                             831                  831
# Rheinische Post                                     2375                 2375
# Stuttgarter Zeitung                                 1237                 1237
# Süddeutsche Zeitung (inkl. Regionalausgaben)        3720                 3720
# aachener zeitung (www)                               168                  168
# der tagesspiegel (www)                               264                  264
# die welt (www)                                       177                  177
# rheinische post (www)                                173                  173
# stuttgarter zeitung (www)                            115                  115
# sueddeutschet politik (www)                          175                  175
#
#                                               reach_dummy  modality_dummy  \
# Newspaper
# Aachener Zeitung                                      970             970
# Der Tagesspiegel                                     1286            1286
# Die Welt                                              831             831
# Rheinische Post                                      2375            2375
# Stuttgarter Zeitung                                  1237            1237
# Süddeutsche Zeitung (inkl. Regionalausgaben)         3720            3720
# aachener zeitung (www)                                168             168
# der tagesspiegel (www)                                264             264
# die welt (www)                                        177             177
# rheinische post (www)                                 173             173
# stuttgarter zeitung (www)                             115             115
# sueddeutschet politik (www)                           175             175
#
#                                               positive words  negative words  \
# Newspaper
# Aachener Zeitung                                         970             970
# Der Tagesspiegel                                        1286            1286
# Die Welt                                                 831             831
# Rheinische Post                                         2375            2375
# Stuttgarter Zeitung                                     1237            1237
# Süddeutsche Zeitung (inkl. Regionalausgaben)            3720            3720
# aachener zeitung (www)                                   168             168
# der tagesspiegel (www)                                   264             264
# die welt (www)                                           177             177
# rheinische post (www)                                    173             173
# stuttgarter zeitung (www)                                115             115
# sueddeutschet politik (www)                              175             175
#
#                                               negativity ratio  \
# Newspaper
# Aachener Zeitung                                           970
# Der Tagesspiegel                                          1286
# Die Welt                                                   831
# Rheinische Post                                           2375
# Stuttgarter Zeitung                                       1237
# Süddeutsche Zeitung (inkl. Regionalausgaben)              3720
# aachener zeitung (www)                                     168
# der tagesspiegel (www)                                     264
# die welt (www)                                             177
# rheinische post (www)                                      173
# stuttgarter zeitung (www)                                  115
# sueddeutschet politik (www)                                175
#
#                                               positivity ratio  emotionality  \
# Newspaper
# Aachener Zeitung                                           970           970
# Der Tagesspiegel                                          1286          1286
# Die Welt                                                   831           831
# Rheinische Post                                           2375          2375
# Stuttgarter Zeitung                                       1237          1237
# Süddeutsche Zeitung (inkl. Regionalausgaben)              3720          3720
# aachener zeitung (www)                                     168           168
# der tagesspiegel (www)                                     264           264
# die welt (www)                                             177           177
# rheinische post (www)                                      173           173
# stuttgarter zeitung (www)                                  115           115
# sueddeutschet politik (www)                                175           175
#
#                                               emotionality ratio
# Newspaper
# Aachener Zeitung                                             970
# Der Tagesspiegel                                            1286
# Die Welt                                                     831
# Rheinische Post                                             2375
# Stuttgarter Zeitung                                         1237
# Süddeutsche Zeitung (inkl. Regionalausgaben)                3720
# aachener zeitung (www)                                       168
# der tagesspiegel (www)                                       264
# die welt (www)                                               177
# rheinische post (www)                                        173
# stuttgarter zeitung (www)                                    115
# sueddeutschet politik (www)                                  175
#
# [12 rows x 21 columns]

# %%
#overview of average values for the newly created columns
df.groupby("Newspaper").mean()
# Out:
#                                                 Unnamed: 0             ID  \
# Newspaper
# Aachener Zeitung                                492.615464     493.615464
# Der Tagesspiegel                              10927.010886   10928.010886
# Die Welt                                       1407.464501    1408.464501
# Rheinische Post                                3486.029474    3487.029474
# Stuttgarter Zeitung                            5749.415521    5750.415521
# Süddeutsche Zeitung (inkl. Regionalausgaben)   8341.211828    8342.211828
# aachener zeitung (www)                         4215.535714  104215.535714
# der tagesspiegel (www)                         4147.094697  104147.094697
# die welt (www)                                 3980.395480  103980.395480
# rheinische post (www)                          4260.479769  104260.479769
# stuttgarter zeitung (www)                      3915.982609  103915.982609
# sueddeutschet politik (www)                    4142.137143  104142.137143
#
#                                                   Length  words in clean text  \
# Newspaper
# Aachener Zeitung                              484.008247           294.691753
# Der Tagesspiegel                              574.946345           345.008554
# Die Welt                                      774.438026           458.566787
# Rheinische Post                               377.456000           227.909895
# Stuttgarter Zeitung                           394.241714           236.194826
# Süddeutsche Zeitung (inkl. Regionalausgaben)  529.366129           312.950806
# aachener zeitung (www)                        401.488095           247.351190
# der tagesspiegel (www)                        574.189394           340.988636
# die welt (www)                                578.751412           346.711864
# rheinische post (www)                         338.699422           206.323699
# stuttgarter zeitung (www)                     279.678261           170.678261
# sueddeutschet politik (www)                   462.925714           274.440000
#
#                                               reach_dummy  modality_dummy  \
# Newspaper
# Aachener Zeitung                                      0.0             1.0
# Der Tagesspiegel                                      1.0             1.0
# Die Welt                                              1.0             1.0
# Rheinische Post                                       0.0             1.0
# Stuttgarter Zeitung                                   0.0             1.0
# Süddeutsche Zeitung (inkl. Regionalausgaben)          1.0             1.0
# aachener zeitung (www)                                0.0             0.0
# der tagesspiegel (www)                                1.0             0.0
# die welt (www)                                        1.0             0.0
# rheinische post (www)                                 0.0             0.0
# stuttgarter zeitung (www)                             0.0             0.0
# sueddeutschet politik (www)                           1.0             0.0
#
#                                               positive words  negative words  \
# Newspaper
# Aachener Zeitung                                    6.880412        2.341237
# Der Tagesspiegel                                    9.789269        3.784603
# Die Welt                                           14.000000        5.649819
# Rheinische Post                                     6.619789        1.952000
# Stuttgarter Zeitung                                 6.800323        2.523848
# Süddeutsche Zeitung (inkl. Regionalausgaben)        9.069355        3.546774
# aachener zeitung (www)                              6.654762        2.839286
# der tagesspiegel (www)                              9.102273        4.329545
# die welt (www)                                      9.548023        4.214689
# rheinische post (www)                               5.248555        2.427746
# stuttgarter zeitung (www)                           4.095652        1.921739
# sueddeutschet politik (www)                         7.777143        3.291429
#
#                                               negativity ratio  \
# Newspaper
# Aachener Zeitung                                      0.009237
# Der Tagesspiegel                                      0.010418
# Die Welt                                              0.011864
# Rheinische Post                                       0.007886
# Stuttgarter Zeitung                                   0.010065
# Süddeutsche Zeitung (inkl. Regionalausgaben)          0.010704
# aachener zeitung (www)                                0.011044
# der tagesspiegel (www)                                0.012720
# die welt (www)                                        0.011909
# rheinische post (www)                                 0.011159
# stuttgarter zeitung (www)                             0.012960
# sueddeutschet politik (www)                           0.011640
#
#                                               positivity ratio  emotionality  \
# Newspaper
# Aachener Zeitung                                      0.027133      9.221649
# Der Tagesspiegel                                      0.027761     13.573872
# Die Welt                                              0.029807     19.649819
# Rheinische Post                                       0.028257      8.571789
# Stuttgarter Zeitung                                   0.027775      9.324171
# Süddeutsche Zeitung (inkl. Regionalausgaben)          0.028514     12.616129
# aachener zeitung (www)                                0.027246      9.494048
# der tagesspiegel (www)                                0.025923     13.431818
# die welt (www)                                        0.026389     13.762712
# rheinische post (www)                                 0.024648      7.676301
# stuttgarter zeitung (www)                             0.025876      6.017391
# sueddeutschet politik (www)                           0.027888     11.068571
#
#                                               emotionality ratio  \
# Newspaper
# Aachener Zeitung                                        0.036370
# Der Tagesspiegel                                        0.038179
# Die Welt                                                0.041671
# Rheinische Post                                         0.036143
# Stuttgarter Zeitung                                     0.037839
# Süddeutsche Zeitung (inkl. Regionalausgaben)            0.039217
# aachener zeitung (www)                                  0.038290
# der tagesspiegel (www)                                  0.038643
# die welt (www)                                          0.038298
# rheinische post (www)                                   0.035807
# stuttgarter zeitung (www)                               0.038836
# sueddeutschet politik (www)                             0.039528
#
#                                               positive words rauh
# Newspaper
# Aachener Zeitung                                        16.123711
# Der Tagesspiegel                                        23.438569
# Die Welt                                                32.687124
# Rheinische Post                                         15.503158
# Stuttgarter Zeitung                                     16.225546
# Süddeutsche Zeitung (inkl. Regionalausgaben)            21.301075
# aachener zeitung (www)                                  15.523810
# der tagesspiegel (www)                                  21.935606
# die welt (www)                                          22.192090
# rheinische post (www)                                   12.294798
# stuttgarter zeitung (www)                               10.095652
# sueddeutschet politik (www)                             17.554286

# %% [markdown]
# ### 5) Assessing emotionality with the Rauh sentiment dictionary

# %%
#read in the rauh dictionary
rauh = pd.read_csv("rauh_sentiment.csv")
#remove whitespaces
rauh["feature"] = rauh["feature"].str.strip()
#inspect the dictionary
rauh.head(3)
# Out:
#     feature  sentiment
# 0     aalen          1
# 1  aalglatt         -1
# 2     aasen         -1

# %%
#split the dictionary into a positive and a negative one
pos_rauh = rauh.loc[rauh["sentiment"] == 1]
neg_rauh = rauh.loc[rauh["sentiment"] == -1]
#delete spaces at the end of each string


#create a list of positive words
pos_list_rauh = []
for e in pos_rauh["feature"]:
    pos_list_rauh.append(e)
#and a list of negative words
neg_list_rauh = []
for e in neg_rauh["feature"]:
    neg_list_rauh.append(e)

# %%
#function to detect positive words
def count_positivewords_rauh(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    poscount = 0
    for w in tokens:
        if w in pos_list_rauh:
            poscount+=1
    return poscount

#function to detect negative words
def count_negativewords_rauh(text):
    doc = nlp(text)
    tokens = [token.text for token in doc]
    negcount = 0
    for w in tokens:
        if w in neg_list_rauh:
            negcount+=1
    return negcount

# %%
#... create a column with the number of positive words
df["positive words rauh"] = [count_positivewords_rauh(text) for text in df["clean text"]]

#... create a column with the number of negative words
df["negative words rauh"] = [count_negativewords_rauh(text) for text in df["clean text"]]

# %%
#inspect the df
df.head(3)
# Out:
#    Unnamed: 0      ID                    Newspaper                 Date  \
# 0           6  100006  sueddeutschet politik (www)  2020-05-28T15:34:08
# 1           8  100008  sueddeutschet politik (www)  2020-05-28T17:01:43
# 2          24  100024       aachener zeitung (www)  2020-05-28T03:01:52
#
#    Length Category Author                                           Headline  \
# 0     367      NaN    NaN  SZ Espresso: Nachrichten kompakt - die Übersic...
# 1     200      NaN    NaN                       Kommunalpolitik: Abgeblendet
# 2     512  Politik    NaN  Länder planen Öffnung: Streit über Schulen und...
#
#                                               Teaser  \
# 0  <p>Was heute wichtig war - und was Sie auf SZ....
# 1                <p>Bayreuths Stadtrat im Stream</p>
# 2  <img src="https://www.aachener-zeitung.de/imgs...
#
#                                              Article  ... reach_dummy  \
# 0  Das Wichtigste zum Coronavirus. Berufstätige M...  ...           1
# 1  Livestream aus dem Stadtrat, das klingt transp...  ...           1
# 2  Der Streit über die Wiederöffnung von Schulen ...  ...           0
#
#   modality_dummy positive words  negative words  negativity ratio  \
# 0              0              8               6          0.026786
# 1              0              2               0          0.000000
# 2              0             11               6          0.018868
#
#    positivity ratio  emotionality  emotionality ratio  positive words rauh  \
# 0          0.035714            14            0.062500                   16
# 1          0.019231             2            0.019231                    3
# 2          0.034591            17            0.053459                   23
#
#    negative words rauh
# 0                   16
# 1                    3
# 2                   18
#
# [3 rows x 24 columns]

# %%
#creating a new column for overall emotionality 
df["emotionality  rauh"] = (df["negative words rauh"]+df["positive words rauh"])
#creating a new column for overall emotionality ratio (percenage of overall words that are positve or negative)
df["emotionality ratio rauh"] = (df["negative words rauh"]+df["positive words rauh"])/df["words in clean text"]
#creating a new column for overall emotionality (percenage of overall words that are negative)
df["negativity ratio rauh"] = df["negative words rauh"]/df["words in clean text"]
#creating a new column for overall emotionality (percenage of overall words that are positve)
df["positivity ratio rauh"] = df["positive words rauh"]/df["words in clean text"]

# %% [markdown]
# ### 6) Computing overall sentiment with the Rauh sentiment dictionary
#
# #### a) Writing a function to compute sentiment

# %%
#Rauh designed an extra dictionary that also includes negations. 
#However, those negations are always the same. 
#I incorporated Rauh's approach towards accounting for negations by creating a seperate negation list and computing sentiment accordingly.

#create a list of negations
negations = ["nicht","nichts","kein","keine","keinen"]
#remove negations from negative list
neg_rauh = neg_rauh[~neg_rauh["feature"].isin(negations)]

def compute_sentiment_rauh(text):
    #tokenise the text
    doc = nlp(text)
    #create a list of sentences
    sentences = [sent.text for sent in doc.sents]
    #create list of words
    wordlist = []
    wordlist_new2 = []
    wordlist_new = []
    #create lists for negations and their sentiment value
    negationlist = []
    sentimentscore_negations = []
    #analyse a document sentence by sentence
    for sentence in sentences:
        #tokenise the sentence
        sentence = nlp(sentence)
        #save tokens as a list
        tokens = [token.text for token in sentence]
        #append the tokens to a list of words
        wordlist.append(tokens[0])
        #check for negations
        for last_item, e in zip(tokens, tokens[1:]):
            if last_item in negations:
                negationlist.append(e)
            else:
                wordlist.append(e)
        #append positive an negative words to a new list
        for e in wordlist:
            if e in pos_list_rauh:
                wordlist_new.append(e)
            elif e in neg_list_rauh:
                wordlist_new.append(e)
    #analyse negationlist and save a list of the words' sentiment value
    for e in negationlist:
        if e in pos_list_rauh:
            sentimentscore_negations.append(-1)
        elif e in neg_list_rauh:
            sentimentscore_negations.append(1)
    #create and merge dataframes
    df1 = pos_rauh[pos_rauh['feature'].isin(wordlist_new)]
    df2 = neg_rauh[neg_rauh['feature'].isin(wordlist_new)]
    dfs = [df1, df2]
    df_final = pd.concat(dfs)
    #compute sentimentscore without negations
    sentimentscore = df_final["sentiment"].sum()
    #compute sentimentscore for only the negations
    sentimentscore_negations = pd.DataFrame(sentimentscore_negations, columns=["sentiment"])
    sentimentscore_negations = sentimentscore_negations["sentiment"].sum()
    #add the two sentiment scores together for a final sentiment value
    sentimentscore_final = sentimentscore + sentimentscore_negations
    return sentimentscore_final

# %% [markdown]
# #### b) Applying the function to calculate both overall sentiment and sentiment ratio

# %%
#compute the sentiment
df["sentimentscore_rauh"] = [compute_sentiment_rauh(text) for text in df["clean text"]]
#calcuate the sentiment ratio to account for length
df["sentimentscore_rauh_ratio"] = df["sentimentscore_rauh"]/df["words in clean text"]

# %% [markdown]
# #### c) Data overview

# %%
#inspect data
df.groupby("Newspaper").mean()
# Out:
#                                                 Unnamed: 0             ID  \
# Newspaper
# Aachener Zeitung                                492.615464     493.615464
# Der Tagesspiegel                              10927.010886   10928.010886
# Die Welt                                       1407.464501    1408.464501
# Rheinische Post                                3486.029474    3487.029474
# Stuttgarter Zeitung                            5749.415521    5750.415521
# Süddeutsche Zeitung (inkl. Regionalausgaben)   8341.211828    8342.211828
# aachener zeitung (www)                         4215.535714  104215.535714
# der tagesspiegel (www)                         4147.094697  104147.094697
# die welt (www)                                 3980.395480  103980.395480
# rheinische post (www)                          4260.479769  104260.479769
# stuttgarter zeitung (www)                      3915.982609  103915.982609
# sueddeutschet politik (www)                    4142.137143  104142.137143
#
#                                                   Length  words in clean text  \
# Newspaper
# Aachener Zeitung                              484.008247           294.691753
# Der Tagesspiegel                              574.946345           345.008554
# Die Welt                                      774.438026           458.566787
# Rheinische Post                               377.456000           227.909895
# Stuttgarter Zeitung                           394.241714           236.194826
# Süddeutsche Zeitung (inkl. Regionalausgaben)  529.366129           312.950806
# aachener zeitung (www)                        401.488095           247.351190
# der tagesspiegel (www)                        574.189394           340.988636
# die welt (www)                                578.751412           346.711864
# rheinische post (www)                         338.699422           206.323699
# stuttgarter zeitung (www)                     279.678261           170.678261
# sueddeutschet politik (www)                   462.925714           274.440000
#
#                                               reach_dummy  modality_dummy  \
# Newspaper
# Aachener Zeitung                                      0.0             1.0
# Der Tagesspiegel                                      1.0             1.0
# Die Welt                                              1.0             1.0
# Rheinische Post                                       0.0             1.0
# Stuttgarter Zeitung                                   0.0             1.0
# Süddeutsche Zeitung (inkl. Regionalausgaben)          1.0             1.0
# aachener zeitung (www)                                0.0             0.0
# der tagesspiegel (www)                                1.0             0.0
# die welt (www)                                        1.0             0.0
# rheinische post (www)                                 0.0             0.0
# stuttgarter zeitung (www)                             0.0             0.0
# sueddeutschet politik (www)                           1.0             0.0
#
#                                               positive words  negative words  \
# Newspaper
# Aachener Zeitung                                    6.880412        2.341237
# Der Tagesspiegel                                    9.789269        3.784603
# Die Welt                                           14.000000        5.649819
# Rheinische Post                                     6.619789        1.952000
# Stuttgarter Zeitung                                 6.800323        2.523848
# Süddeutsche Zeitung (inkl. Regionalausgaben)        9.069355        3.546774
# aachener zeitung (www)                              6.654762        2.839286
# der tagesspiegel (www)                              9.102273        4.329545
# die welt (www)                                      9.548023        4.214689
# rheinische post (www)                               5.248555        2.427746
# stuttgarter zeitung (www)                           4.095652        1.921739
# sueddeutschet politik (www)                         7.777143        3.291429
#
#                                               negativity ratio  \
# Newspaper
# Aachener Zeitung                                      0.009237
# Der Tagesspiegel                                      0.010418
# Die Welt                                              0.011864
# Rheinische Post                                       0.007886
# Stuttgarter Zeitung                                   0.010065
# Süddeutsche Zeitung (inkl. Regionalausgaben)          0.010704
# aachener zeitung (www)                                0.011044
# der tagesspiegel (www)                                0.012720
# die welt (www)                                        0.011909
# rheinische post (www)                                 0.011159
# stuttgarter zeitung (www)                             0.012960
# sueddeutschet politik (www)                           0.011640
#
#                                               positivity ratio  emotionality  \
# Newspaper
# Aachener Zeitung                                      0.027133      9.221649
# Der Tagesspiegel                                      0.027761     13.573872
# Die Welt                                              0.029807     19.649819
# Rheinische Post                                       0.028257      8.571789
# Stuttgarter Zeitung                                   0.027775      9.324171
# Süddeutsche Zeitung (inkl. Regionalausgaben)          0.028514     12.616129
# aachener zeitung (www)                                0.027246      9.494048
# der tagesspiegel (www)                                0.025923     13.431818
# die welt (www)                                        0.026389     13.762712
# rheinische post (www)                                 0.024648      7.676301
# stuttgarter zeitung (www)                             0.025876      6.017391
# sueddeutschet politik (www)                           0.027888     11.068571
#
#                                               emotionality ratio  \
# Newspaper
# Aachener Zeitung                                        0.036370
# Der Tagesspiegel                                        0.038179
# Die Welt                                                0.041671
# Rheinische Post                                         0.036143
# Stuttgarter Zeitung                                     0.037839
# Süddeutsche Zeitung (inkl. Regionalausgaben)            0.039217
# aachener zeitung (www)                                  0.038290
# der tagesspiegel (www)                                  0.038643
# die welt (www)                                          0.038298
# rheinische post (www)                                   0.035807
# stuttgarter zeitung (www)                               0.038836
# sueddeutschet politik (www)                             0.039528
#
#                                               positive words rauh  \
# Newspaper
# Aachener Zeitung                                        16.123711
# Der Tagesspiegel                                        23.438569
# Die Welt                                                32.687124
# Rheinische Post                                         15.503158
# Stuttgarter Zeitung                                     16.225546
# Süddeutsche Zeitung (inkl. Regionalausgaben)            21.301075
# aachener zeitung (www)                                  15.523810
# der tagesspiegel (www)                                  21.935606
# die welt (www)                                          22.192090
# rheinische post (www)                                   12.294798
# stuttgarter zeitung (www)                               10.095652
# sueddeutschet politik (www)                             17.554286
#
#                                               negative words rauh  \
# Newspaper
# Aachener Zeitung                                        11.380412
# Der Tagesspiegel                                        17.987558
# Die Welt                                                25.820698
# Rheinische Post                                          9.561263
# Stuttgarter Zeitung                                     11.839935
# Süddeutsche Zeitung (inkl. Regionalausgaben)            15.922312
# aachener zeitung (www)                                  14.327381
# der tagesspiegel (www)                                  20.412879
# die welt (www)                                          19.994350
# rheinische post (www)                                   12.104046
# stuttgarter zeitung (www)                                9.147826
# sueddeutschet politik (www)                             16.382857
#
#                                               emotionality  rauh  \
# Newspaper
# Aachener Zeitung                                       27.504124
# Der Tagesspiegel                                       41.426128
# Die Welt                                               58.507822
# Rheinische Post                                        25.064421
# Stuttgarter Zeitung                                    28.065481
# Süddeutsche Zeitung (inkl. Regionalausgaben)           37.223387
# aachener zeitung (www)                                 29.851190
# der tagesspiegel (www)                                 42.348485
# die welt (www)                                         42.186441
# rheinische post (www)                                  24.398844
# stuttgarter zeitung (www)                              19.243478
# sueddeutschet politik (www)                            33.937143
#
#                                               emotionality ratio rauh  \
# Newspaper
# Aachener Zeitung                                             0.107716
# Der Tagesspiegel                                             0.116717
# Die Welt                                                     0.125908
# Rheinische Post                                              0.105901
# Stuttgarter Zeitung                                          0.114090
# Süddeutsche Zeitung (inkl. Regionalausgaben)                 0.115467
# aachener zeitung (www)                                       0.118968
# der tagesspiegel (www)                                       0.123896
# die welt (www)                                               0.118053
# rheinische post (www)                                        0.116459
# stuttgarter zeitung (www)                                    0.116795
# sueddeutschet politik (www)                                  0.119188
#
#                                               negativity ratio rauh  \
# Newspaper
# Aachener Zeitung                                           0.044877
# Der Tagesspiegel                                           0.050711
# Die Welt                                                   0.056057
# Rheinische Post                                            0.039766
# Stuttgarter Zeitung                                        0.047511
# Süddeutsche Zeitung (inkl. Regionalausgaben)               0.048909
# aachener zeitung (www)                                     0.056615
# der tagesspiegel (www)                                     0.060853
# die welt (www)                                             0.057265
# rheinische post (www)                                      0.058407
# stuttgarter zeitung (www)                                  0.055602
# sueddeutschet politik (www)                                0.057424
#
#                                               positivity ratio rauh
# Newspaper
# Aachener Zeitung                                           0.062839
# Der Tagesspiegel                                           0.066006
# Die Welt                                                   0.069851
# Rheinische Post                                            0.066135
# Stuttgarter Zeitung                                        0.066580
# Süddeutsche Zeitung (inkl. Regionalausgaben)               0.066559
# aachener zeitung (www)                                     0.062353
# der tagesspiegel (www)                                     0.063043
# die welt (www)                                             0.060788
# rheinische post (www)                                      0.058051
# stuttgarter zeitung (www)                                  0.061192
# sueddeutschet politik (www)                                0.061764

# %% [markdown]
# ## 7) Saving the data

# %%
df.to_excel("complete_data_cleaned_with_emotionality.xlsx")
